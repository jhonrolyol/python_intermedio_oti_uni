# %% [markdown]
# # POO
#
# * Paradigma : Definir a los programas en terminos de `clases de objetos`
# * objeto : Son entidades que combinan : estado , compotamiento e identidad.
#
# ## Caracteristicas
# * Reutilizacion del codigo.
# * Permite crear sistemas mas complejos.
# * Relacionamos el sistema que buscamos desarrollar con el mundo real.
# * Facilita la creacion de software con interfez grafica de usuario (GUI) : PyQT (basada libreria QT), WxPython (basado en WxWidgets),
# Tkinter, Kivy, PySimpleGUI, PySide.
# * Construccion de prototipos.
# * Agiliza el desarrollo de software
# * Facilita el mantenimiento (Depende del diseño)
# * Facilita el trabajo en equipo (Depende del diseño)
#
# ## Elementos de la POO
# * Clase
# * Objetos
# * Mensajes
# * Herencia
# * Polimorfismo

# %%
# Definamos la clase Circulo

class Circulo:
  """
  Una instancia de la clase Circulo modela un circulo con su respectivo radio
  y puede realizar algunas operaciones :
    * Calcular el area del circulo
    * Calcular el perimetro del circulo
  """

  # Metodo __init__ : Como el usuario va instanciar en un objeto a la clase Circulo
  def __init__(self, radio = 1.0):
    """
    El constructor de la clase Circulo con radio (opcional/con valor por defecto) igual a 1.0
    """
    self.radio = radio

  # Metodo __str__
  def __str__(self):
    """
    Retorna un string que sirve para interoperar con print y str
    """
    return "Circulo de radio %.3f" %self.radio

  # metodo __repr__
  def __repr__(self):
    """
    Retorna un string usado para recrear la instancia
    """
    return "Circulo(radio = %.3f)" %self.radio

  # Hasta este punto
  # Realicemos una primera prueba de la clase Circulo

  # Continuemos agregando metodos propios de la clase Circulo:
    # Calcular el area del circulo
    # Calcular el perimetro del circulo
  def calculo_area(self):
    """
    Este metodo implementa el calculo del area de una instancia de la clase Circulo
    """
    return 3.1415*(self.radio)**2

  def calculo_perimetro(self):
    """
    Metodo que implementa el calculo del perimetro de una instancia de la clase Circulo
    """
    return 2*3.1415*self.radio

# %%
# Primera Prueba (hasta la linea 30 del codigo fuente de la clase Circulo)
Cx = Circulo()

# %%
# La celda anterior ya creo al objeto Cx en memoria
Cx
# Observamos el resultado de que se aplico el metodo __repr__
# Out:
# Circulo(radio = 1.000)

# %%
print(Cx)
# Observamos el resultado de que se ejecuto el metodo __str__
# Out:
# Circulo de radio 1.000

# %%
# Una vez agregados los metodos calcula_area y calcula_perimetro

# Definamos una instancia de la clase Circulo
c1 = Circulo()
c2 = Circulo(radio = 3.71)

# Carguemos el modulo math
import math as m
c3 = Circulo(m.e**(0.333*m.pi))

# %%
# Tipo de dato
type(Cx)
# Out:
# __main__.Circulo

# %%
# Lista de metodos
dir(c1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'calculo_area',
#  'calculo_perimetro',
#  'radio']

# %%
# Documentacion del metodo calculo_perimetros
help(Cx.calculo_perimetro)
# Out:
# Help on method calculo_perimetro in module __main__:
#
# calculo_perimetro() method of __main__.Circulo instance
#     Metodo que implementa el calculo del perimetro de una instancia de la clase Circulo

# %%
# El metodo __doc__
print(c1.__doc__)
# Out:
#   Una instancia de la clase Circulo modela un circulo con su respectivo radio
#   y puede realizar algunas operaciones :
#     * Calcular el area del circulo
#     * Calcular el perimetro del circulo

# %%
# El metodoo __doc__ del metodo calcula_area
print(c3.calculo_area.__doc__)
# Out:
#     Este metodo implementa el calculo del area de una instancia de la clase Circulo

# %%
# Funcion isinstance :
isinstance(c1, list)
# Out:
# False

# %%
isinstance(c1, dict)
# Out:
# False

# %%
isinstance(c1, Circulo)
# Out:
# True
