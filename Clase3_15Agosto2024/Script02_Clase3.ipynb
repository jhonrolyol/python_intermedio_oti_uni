# %%
# Interactuemos con el sistema de archivos de la computadora que GCE provee
# para cargar archivos de datos (texto plano)

# %%
# Modulo os
import os
os.listdir()
# Out:
# ['.config', 'babyNamesUSYOB-mostpopular.csv', 'sample_data']

# %%
# Carguemos 'babyNamesUSYOB-mostpopular.csv' a memoria ram
# Mostremos cada una de sus filas
import csv
with open('babyNamesUSYOB-mostpopular.csv', "r") as file:
  lecturaCSV = csv.reader(file)
  for fila in lecturaCSV:
    print(fila)
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
# ['2014', 'Everett', 'M', '2535']
# ['2014', 'Brian', 'M', '2518']
# ['2014', 'Jeremy', 'M', '2512']
# ['2014', 'Alan', 'M', '2494']
# ['2014', 'Kaden', 'M', '2456']
# ['2014', 'Jaden', 'M', '2443']
# ['2014', 'Riley', 'M', '2439']
# ['2014', 'Jesse', 'M', '2438']
# ['2014', 'King', 'M', '2427']
# ['2014', 'Tucker', 'M', '2413']
# ['2014', 'Kai', 'M', '2397']
# ['2014', 'Kyle', 'M', '2377']
# ['2014', 'Abraham', 'M', '2368']
# ['2014', 'Malachi', 'M', '2367']
# ['2014', 'Ezekiel', 'M', '2360']
# ['2014', 'Calvin', 'M', '2326']
# ['2014', 'Bradley', 'M', '2319']
# ['2014', 'Oscar', 'M', '2316']
# ['2014', 'Luca', 'M', '2301']
# ['2014', 'Avery', 'M', '2278']
# ['2014', 'Aidan', 'M', '2274']
# ['2014', 'Zayden', 'M', '2216']
# ['2014', 'Mark', 'M', '2170']
# ['2014', 'Jake', 'M', '2160']
# ['2014', 'Kenneth', 'M', '2140']
# ['2014', 'Maximus', 'M', '2131']
# ['2014', 'Sean', 'M', '2119']
# ['2014', 'Karter', 'M', '2108']
# ['2014', 'Brady', 'M', '2090']
# ['2014', 'Nicolas', 'M', '2069']
# ['2014', 'Caden', 'M', '2048']
# ['2014', 'Cayden', 'M', '2044']
# ['2014', 'Graham', 'M', '2037']
# ['2014', 'Jayceon', 'M', '2009']
# ['2014', 'Paul', 'M', '1996']
# ['2014', 'Gage', 'M', '1931']
# ['2014', 'Corbin', 'M', '1919']
# ['2014', 'Peter', 'M', '1910']
# ['2014', 'Derek', 'M', '1877']
# ['2014', 'Maverick', 'M', '1874']
# ['2014', 'Tanner', 'M', '1851']
# ['2014', 'Jorge', 'M', '1846']
# ['2014', 'Jax', 'M', '1843']
# ['2014', 'Peyton', 'M', '1838']
# ['2014', 'Xander', 'M', '1828']
# ['2014', 'Amir', 'M', '1812']
# ['2014', 'Gael', 'M', '1807']
# ['2014', 'Omar', 'M', '1802']
# ['2014', 'Iker', 'M', '1789']
# ['2014', 'Elliot', 'M', '1765']
# ['2014', 'Javier', 'M', '1762']
# ['2014', 'Jasper', 'M', '1742']
# ['2014', 'Cody', 'M', '1735']
# ['2014', 'Rylan', 'M', '1734']
# ['2014', 'Andres', 'M', '1706']
# ['2014', 'Dean', 'M', '1705']
# ['2014', 'Collin', 'M', '1695']
# ['2014', 'Zane', 'M', '1686']
# ['2014', 'Charlie', 'M', '1683']
# ['2014', 'Myles', 'M', '1664']
# ['2014', 'Lorenzo', 'M', '1632']
# ['2014', 'Beau', 'M', '1630']
# ['2014', 'Conner', 'M', '1630']
# ['2014', 'Lukas', 'M', '1627']
# ['2014', 'Simon', 'M', '1613']
# ['2014', 'Francisco', 'M', '1593']
# ['2014', 'Elliott', 'M', '1583']
# ['2014', 'Finn', 'M', '1580']
# ['2014', 'Gunner', 'M', '1575']
# ['2014', 'Garrett', 'M', '1557']
# ['2014', 'Jaiden', 'M', '1556']
# ['2014', 'Keegan', 'M', '1552']
# ['2014', 'Rowan', 'M', '1542']
# ['2014', 'Griffin', 'M', '1535']
# ['2014', 'Judah', 'M', '1533']
# ['2014', 'August', 'M', '1531']
# ['2014', 'Israel', 'M', '1528']
# ['2014', 'Beckett', 'M', '1521']
# ['2014', 'Brooks', 'M', '1517']
# ['2014', 'Chance', 'M', '1516']
# ['2014', 'Zander', 'M', '1515']
# ['2014', 'Spencer', 'M', '1511']
# ['2014', 'Damien', 'M', '1504']
# ['2014', 'Seth', 'M', '1499']
# ['2014', 'Waylon', 'M', '1494']
# ['2014', 'Travis', 'M', '1485']
# ['2014', 'Devin', 'M', '1481']
# ['2014', 'Zion', 'M', '1477']
# ['2014', 'Emiliano', 'M', '1476']
# ['2014', 'Ricardo', 'M', '1460']
# ['2014', 'Erick', 'M', '1440']
# ['2014', 'Stephen', 'M', '1439']
# ['2014', 'Reid', 'M', '1430']
# ['2014', 'Martin', 'M', '1429']
# ['2014', 'Eduardo', 'M', '1426']
# ['2014', 'Paxton', 'M', '1426']
# ['2014', 'Fernando', 'M', '1399']
# ['2014', 'Raymond', 'M', '1397']
# ['2014', 'Manuel', 'M', '1376']
# ['2014', 'Jeffrey', 'M', '1373']
# ['2014', 'Felix', 'M', '1369']
# ['2014', 'Josue', 'M', '1362']
# ['2014', 'Dallas', 'M', '1361']
# ['2014', 'Mario', 'M', '1361']
# ['2014', 'Clayton', 'M', '1354']
# ['2014', 'Caiden', 'M', '1352']
# ['2014', 'Cristian', 'M', '1339']
# ['2014', 'Troy', 'M', '1322']
# ['2014', 'Cash', 'M', '1320']
# ['2014', 'Trevor', 'M', '1318']
# ['2014', 'Shane', 'M', '1293']
# ['2014', 'Kameron', 'M', '1286']
# ['2014', 'Cesar', 'M', '1283']
# ['2014', 'Emilio', 'M', '1277']
# ['2014', 'Andre', 'M', '1270']
# ['2014', 'Tyson', 'M', '1269']
# ['2014', 'Andy', 'M', '1266']
# ['2014', 'Titus', 'M', '1263']
# ['2014', 'Donovan', 'M', '1259']
# ['2014', 'Knox', 'M', '1241']
# ['2014', 'River', 'M', '1235']
# ['2014', 'Kyler', 'M', '1223']
# ['2014', 'Louis', 'M', '1220']
# ['2014', 'Cruz', 'M', '1219']
# ['2014', 'Holden', 'M', '1215']
# ['2014', 'Hector', 'M', '1212']
# ['2014', 'Rafael', 'M', '1201']
# ['2014', 'Landen', 'M', '1199']
# ['2014', 'Lane', 'M', '1195']
# ['2014', 'Jared', 'M', '1186']
# ['2014', 'Messiah', 'M', '1182']
# ['2014', 'Edwin', 'M', '1181']
# ['2014', 'Johnny', 'M', '1180']
# ['2014', 'Archer', 'M', '1179']
# ['2014', 'Johnathan', 'M', '1179']
# ['2014', 'Edgar', 'M', '1177']
# ['2014', 'Alexis', 'M', '1175']
# ['2014', 'Anderson', 'M', '1159']
# ['2014', 'Trenton', 'M', '1149']
# ['2014', 'Arthur', 'M', '1143']
# ['2014', 'Sergio', 'M', '1139']
# ['2014', 'Marco', 'M', '1125']
# ['2014', 'Julius', 'M', '1123']
# ['2014', 'Dominick', 'M', '1120']
# ['2014', 'Milo', 'M', '1114']
# ['2014', 'Dalton', 'M', '1109']
# ['2014', 'Remington', 'M', '1105']
# ['2014', 'Gregory', 'M', '1103']
# ['2014', 'Dante', 'M', '1102']
# ['2014', 'Angelo', 'M', '1100']
# ['2014', 'Reed', 'M', '1093']
# ['2014', 'Jaylen', 'M', '1088']
# ['2014', 'Marshall', 'M', '1082']
# ['2014', 'Dawson', 'M', '1078']
# ['2014', 'Leon', 'M', '1077']
# ['2014', 'Drew', 'M', '1057']
# ['2014', 'Emerson', 'M', '1053']
# ['2014', 'Shawn', 'M', '1052']
# ['2014', 'Fabian', 'M', '1048']
# ['2014', 'Joaquin', 'M', '1042']
# ['2014', 'Walker', 'M', '1040']
# ['2014', 'Erik', 'M', '1035']
# ['2014', 'Desmond', 'M', '1031']
# ['2014', 'Karson', 'M', '1031']
# ['2014', 'Emanuel', 'M', '1019']
# ['2014', 'Jett', 'M', '1017']
# ['2014', 'Ali', 'M', '1009']
# ['2014', 'Kendrick', 'M', '1009']
# ['2014', 'Aden', 'M', '994']
# ['2014', 'Frank', 'M', '988']
# ['2014', 'Walter', 'M', '982']
# ['2014', 'Colt', 'M', '976']
# ['2014', 'Amari', 'M', '975']
# ['2014', 'Rhett', 'M', '975']
# ['2014', 'Romeo', 'M', '967']
# ['2014', 'Cohen', 'M', '964']
# ['2014', 'Roberto', 'M', '962']
# ['2014', 'Maximiliano', 'M', '959']
# ['2014', 'Barrett', 'M', '957']
# ['2014', 'Grady', 'M', '955']
# ['2014', 'Zaiden', 'M', '953']
# ['2014', 'Drake', 'M', '940']
# ['2014', 'Gideon', 'M', '939']
# ['2014', 'Major', 'M', '925']
# ['2014', 'Brendan', 'M', '919']
# ['2014', 'Skyler', 'M', '913']
# ['2014', 'Derrick', 'M', '909']
# ['2014', 'Phoenix', 'M', '906']
# ['2014', 'Pedro', 'M', '903']
# ['2014', 'Noel', 'M', '899']
# ['2014', 'Ruben', 'M', '891']
# ['2014', 'Braden', 'M', '890']
# ['2014', 'Dakota', 'M', '883']
# ['2014', 'Nehemiah', 'M', '883']
# ['2014', 'Cade', 'M', '877']
# ['2014', 'Kamden', 'M', '874']
# ['2014', 'Quinn', 'M', '874']
# ['2014', 'Nash', 'M', '869']
# ['2014', 'Kason', 'M', '868']
# ['2014', 'Ronan', 'M', '864']
# ['2014', 'Allen', 'M', '856']
# ['2014', 'Porter', 'M', '856']
# ['2014', 'Atticus', 'M', '852']
# ['2014', 'Enzo', 'M', '849']
# ['2014', 'Jay', 'M', '840']
# ['2014', 'Kash', 'M', '837']
# ['2014', 'Matteo', 'M', '835']
# ['2014', 'Adan', 'M', '834']
# ['2014', 'Finley', 'M', '832']
# ['2014', 'Malik', 'M', '832']
# ['2014', 'Abram', 'M', '828']
# ['2014', 'Braylon', 'M', '828']
# ['2014', 'Solomon', 'M', '826']
# ['2014', 'Ace', 'M', '819']
# ['2014', 'Orion', 'M', '817']
# ['2014', 'Gunnar', 'M', '813']
# ['2014', 'Clark', 'M', '811']
# ['2014', 'Ismael', 'M', '806']
# ['2014', 'Kellan', 'M', '806']
# ['2014', 'Brennan', 'M', '805']
# ['2014', 'Corey', 'M', '805']
# ['2014', 'Tate', 'M', '801']
# ['2014', 'Philip', 'M', '795']
# ['2014', 'Thiago', 'M', '795']
# ['2014', 'Phillip', 'M', '792']
# ['2014', 'Esteban', 'M', '790']
# ['2014', 'Jayson', 'M', '790']
# ['2014', 'Jensen', 'M', '789']
# ['2014', 'Dexter', 'M', '786']
# ['2014', 'Ronald', 'M', '786']
# ['2014', 'Pablo', 'M', '784']
# ['2014', 'Dillon', 'M', '783']
# ['2014', 'Muhammad', 'M', '774']
# ['2014', 'Armando', 'M', '772']
# ['2014', 'Bruce', 'M', '772']
# ['2014', 'Gerardo', 'M', '771']
# ['2014', 'Brycen', 'M', '767']
# ['2014', 'Marcos', 'M', '767']
# ['2014', 'Kade', 'M', '766']
# ['2014', 'Damon', 'M', '759']
# ['2014', 'Kolton', 'M', '758']
# ['2014', 'Braylen', 'M', '755']
# ['2014', 'Russell', 'M', '755']
# ['2014', 'Prince', 'M', '753']
# ['2014', 'Leland', 'M', '751']
# ['2014', 'Gannon', 'M', '749']
# ['2014', 'Milan', 'M', '749']
# ['2014', 'Keith', 'M', '747']
# ['2014', 'Enrique', 'M', '745']
# ['2014', 'Rory', 'M', '744']
# ['2014', 'Brock', 'M', '742']
# ['2014', 'Donald', 'M', '734']
# ['2014', 'Tobias', 'M', '731']
# ['2014', 'Deacon', 'M', '730']
# ['2014', 'Chandler', 'M', '727']
# ['2014', 'Cason', 'M', '724']
# ['2014', 'Raul', 'M', '724']
# ['2014', 'Scott', 'M', '720']
# ['2014', 'Ty', 'M', '717']
# ['2014', 'Colby', 'M', '713']
# ['2014', 'Landyn', 'M', '712']
# ['2014', 'Mohamed', 'M', '711']
# ['2014', 'Leonel', 'M', '709']
# ['2014', 'Danny', 'M', '704']
# ['2014', 'Kayson', 'M', '703']
# ['2014', 'Hugo', 'M', '694']
# ['2014', 'Warren', 'M', '694']
# ['2014', 'Adriel', 'M', '693']
# ['2014', 'Dustin', 'M', '693']
# ['2014', 'Ryland', 'M', '693']
# ['2014', 'Albert', 'M', '692']
# ['2014', 'Taylor', 'M', '692']
# ['2014', 'Keaton', 'M', '690']
# ['2014', 'Jamison', 'M', '687']
# ['2014', 'Ari', 'M', '685']
# ['2014', 'Ellis', 'M', '678']
# ['2014', 'Malcolm', 'M', '678']
# ['2014', 'Kellen', 'M', '669']
# ['2014', 'Maximilian', 'M', '667']
# ['2014', 'Davis', 'M', '666']
# ['2014', 'Saul', 'M', '661']
# ['2014', 'Tony', 'M', '660']
# ['2014', 'Zachariah', 'M', '660']
# ['2014', 'Franklin', 'M', '655']
# ['2014', 'Rocco', 'M', '654']
# ['2014', 'Jerry', 'M', '653']
# ['2014', 'Julio', 'M', '652']
# ['2014', 'Arjun', 'M', '650']
# ['2014', 'Ibrahim', 'M', '647']
# ['2014', 'Nico', 'M', '647']
# ['2014', 'Jaxton', 'M', '645']
# ['2014', 'Jakob', 'M', '641']
# ['2014', 'Izaiah', 'M', '636']
# ['2014', 'Cyrus', 'M', '635']
# ['2014', 'Moises', 'M', '633']
# ['2014', 'Lawrence', 'M', '632']
# ['2014', 'Sullivan', 'M', '631']
# ['2014', 'Finnegan', 'M', '627']
# ['2014', 'Khalil', 'M', '625']
# ['2014', 'Mathew', 'M', '622']
# ['2014', 'Case', 'M', '619']
# ['2014', 'Alec', 'M', '618']
# ['2014', 'Jaime', 'M', '618']
# ['2014', 'Pierce', 'M', '618']
# ['2014', 'Quentin', 'M', '614']
# ['2014', 'Darius', 'M', '611']
# ['2014', 'Kasen', 'M', '611']
# ['2014', 'Colten', 'M', '608']
# ['2014', 'Royce', 'M', '601']
# ['2014', 'Odin', 'M', '600']
# ['2014', 'Kane', 'M', '593']
# ['2014', 'Francis', 'M', '592']
# ['2014', 'Raiden', 'M', '592']
# ['2014', 'Daxton', 'M', '588']
# ['2014', 'Trey', 'M', '588']
# ['2014', 'Gustavo', 'M', '583']
# ['2014', 'Moses', 'M', '580']
# ['2014', 'Rhys', 'M', '580']
# ['2014', 'Alijah', 'M', '577']
# ['2014', 'Lawson', 'M', '576']
# ['2014', 'Rodrigo', 'M', '575']
# ['2014', 'Beckham', 'M', '574']
# ['2014', 'Harvey', 'M', '574']
# ['2014', 'Dennis', 'M', '573']
# ['2014', 'Uriel', 'M', '573']
# ['2014', 'Armani', 'M', '570']
# ['2014', 'Marvin', 'M', '568']
# ['2014', 'Frederick', 'M', '566']
# ['2014', 'Kian', 'M', '566']
# ['2014', 'Darren', 'M', '565']
# ['2014', 'Mohammed', 'M', '565']
# ['2014', 'Raylan', 'M', '565']
# ['2014', 'Trent', 'M', '563']
# ['2014', 'Callen', 'M', '561']
# ['2014', 'Jonas', 'M', '560']
# ['2014', 'Zayne', 'M', '559']
# ['2014', 'Matias', 'M', '558']
# ['2014', 'Mitchell', 'M', '557']
# ['2014', 'Uriah', 'M', '556']
# ['2014', 'Kyrie', 'M', '555']
# ['2014', 'Sterling', 'M', '549']
# ['2014', 'Tristen', 'M', '549']
# ['2014', 'Theo', 'M', '548']
# ['2014', 'Randy', 'M', '544']
# ['2014', 'Killian', 'M', '543']
# ['2014', 'Larry', 'M', '543']
# ['2014', 'Korbin', 'M', '541']
# ['2014', 'Alberto', 'M', '540']
# ['2014', 'Ricky', 'M', '540']
# ['2014', 'Princeton', 'M', '539']
# ['2014', 'Chris', 'M', '537']
# ['2014', 'Malakai', 'M', '537']
# ['2014', 'Asa', 'M', '536']
# ['2014', 'Gianni', 'M', '536']
# ['2014', 'Arturo', 'M', '535']
# ['2014', 'Jimmy', 'M', '533']
# ['2014', 'Aarav', 'M', '531']
# ['2014', 'Benson', 'M', '527']
# ['2014', 'Alfredo', 'M', '525']
# ['2014', 'Braydon', 'M', '525']
# ['2014', 'Alonzo', 'M', '524']
# ['2014', 'Devon', 'M', '524']
# ['2014', 'Justice', 'M', '523']
# ['2014', 'Casey', 'M', '521']
# ['2014', 'Curtis', 'M', '521']
# ['2014', 'Moshe', 'M', '521']
# ['2014', 'Sam', 'M', '520']
# ['2014', 'Roy', 'M', '519']
# ['2014', 'Arlo', 'M', '518']
# ['2014', 'Legend', 'M', '518']
# ['2014', 'Winston', 'M', '516']
# ['2014', 'Dorian', 'M', '515']
# ['2014', 'Nikolai', 'M', '515']
# ['2014', 'Kobe', 'M', '512']
# ['2014', 'Reece', 'M', '512']
# ['2014', 'Cannon', 'M', '507']
# ['2014', 'Lance', 'M', '507']
# ['2014', 'Wade', 'M', '507']
# ['2014', 'Hayes', 'M', '503']
# ['2014', 'Augustus', 'M', '501']
# ['2014', 'Hendrix', 'M', '500']
# ['2014', 'Ahmed', 'M', '499']
# ['2014', 'Isaias', 'M', '499']
# ['2014', 'Neymar', 'M', '499']
# ['2014', 'Issac', 'M', '498']
# ['2014', 'Brayan', 'M', '497']
# ['2014', 'Jaxen', 'M', '497']
# ['2014', 'Nasir', 'M', '497']
# ['2014', 'Boston', 'M', '495']
# ['2014', 'Ronin', 'M', '494']
# ['2014', 'Talon', 'M', '494']
# ['2014', 'Luka', 'M', '493']
# ['2014', 'Leonidas', 'M', '492']
# ['2014', 'Gary', 'M', '491']
# ['2014', 'Orlando', 'M', '491']
# ['2014', 'Vihaan', 'M', '491']
# ['2014', 'Bowen', 'M', '490']
# ['2014', 'Nikolas', 'M', '490']
# ['2014', 'Quinton', 'M', '490']
# ['2014', 'Yahir', 'M', '490']
# ['2014', 'Luciano', 'M', '489']
# ['2014', 'Ezequiel', 'M', '488']
# ['2014', 'Joe', 'M', '488']
# ['2014', 'Royal', 'M', '488']
# ['2014', 'Ahmad', 'M', '487']
# ['2014', 'Ayaan', 'M', '484']
# ['2014', 'Jalen', 'M', '483']
# ['2014', 'Kieran', 'M', '483']
# ['2014', 'Jamari', 'M', '482']
# ['2014', 'Noe', 'M', '482']
# ['2014', 'Mauricio', 'M', '481']
# ['2014', 'Matthias', 'M', '480']
# ['2014', 'Conor', 'M', '479']
# ['2014', 'Johan', 'M', '477']
# ['2014', 'Maurice', 'M', '476']
# ['2014', 'Bryant', 'M', '474']
# ['2014', 'Roger', 'M', '474']
# ['2014', 'Lennox', 'M', '473']
# ['2014', 'Mathias', 'M', '473']
# ['2014', 'Nathanael', 'M', '472']
# ['2014', 'Nixon', 'M', '469']
# ['2014', 'Yusuf', 'M', '469']
# ['2014', 'Mohammad', 'M', '468']
# ['2014', 'Jacoby', 'M', '465']
# ['2014', 'Tatum', 'M', '465']
# ['2014', 'Eddie', 'M', '464']
# ['2014', 'Kristopher', 'M', '463']
# ['2014', 'Lewis', 'M', '461']
# ['2014', 'Raphael', 'M', '460']
# ['2014', 'Wilson', 'M', '460']
# ['2014', 'Alvin', 'M', '458']
# ['2014', 'Douglas', 'M', '455']
# ['2014', 'Mekhi', 'M', '453']
# ['2014', 'Eden', 'M', '449']
# ['2014', 'Salvador', 'M', '449']
# ['2014', 'Dax', 'M', '448']
# ['2014', 'Hank', 'M', '448']
# ['2014', 'Cullen', 'M', '446']
# ['2014', 'Toby', 'M', '444']
# ['2014', 'Lucian', 'M', '440']
# ['2014', 'Emmitt', 'M', '439']
# ['2014', 'Rayan', 'M', '439']
# ['2014', 'Jefferson', 'M', '437']
# ['2014', 'Roland', 'M', '437']
# ['2014', 'Casen', 'M', '435']
# ['2014', 'Crosby', 'M', '435']
# ['2014', 'Carl', 'M', '434']
# ['2014', 'London', 'M', '434']
# ['2014', 'Bodhi', 'M', '433']
# ['2014', 'Dominik', 'M', '432']
# ['2014', 'Niko', 'M', '430']
# ['2014', 'Zackary', 'M', '429']
# ['2014', 'Deandre', 'M', '427']
# ['2014', 'Hamza', 'M', '426']
# ['2014', 'Remy', 'M', '425']
# ['2014', 'Sincere', 'M', '424']
# ['2014', 'Quincy', 'M', '423']
# ['2014', 'Alessandro', 'M', '422']
# ['2014', 'Dane', 'M', '421']
# ['2014', 'Terry', 'M', '420']
# ['2014', 'Samson', 'M', '418']
# ['2014', 'Layne', 'M', '417']
# ['2014', 'Otto', 'M', '417']
# ['2014', 'Madden', 'M', '416']
# ['2014', 'Jasiah', 'M', '415']
# ['2014', 'Santino', 'M', '415']
# ['2014', 'Rohan', 'M', '413']
# ['2014', 'Abdullah', 'M', '412']
# ['2014', 'Bo', 'M', '412']
# ['2014', 'Brentley', 'M', '411']
# ['2014', 'Skylar', 'M', '411']
# ['2014', 'Soren', 'M', '411']
# ['2014', 'Atlas', 'M', '410']
# ['2014', 'Layton', 'M', '410']
# ['2014', 'Marc', 'M', '410']
# ['2014', 'Kyson', 'M', '409']
# ['2014', 'Harley', 'M', '407']
# ['2014', 'Nelson', 'M', '407']
# ['2014', 'Payton', 'M', '407']
# ['2014', 'Aldo', 'M', '406']
# ['2014', 'Conrad', 'M', '406']
# ['2014', 'Reese', 'M', '405']
# ['2014', 'Morgan', 'M', '404']
# ['2014', 'Ramon', 'M', '404']
# ['2014', 'Sage', 'M', '404']
# ['2014', 'Ernesto', 'M', '401']
# ['2014', 'Carmelo', 'M', '400']
# ['2014', 'Byron', 'M', '399']
# ['2014', 'Kristian', 'M', '398']
# ['2014', 'Neil', 'M', '397']
# ['2014', 'Oakley', 'M', '397']
# ['2014', 'Flynn', 'M', '391']
# ['2014', 'Tomas', 'M', '390']
# ['2014', 'Kylan', 'M', '388']
# ['2014', 'Lionel', 'M', '388']
# ['2014', 'Rex', 'M', '387']
# ['2014', 'Jeffery', 'M', '385']
# ['2014', 'Leonard', 'M', '385']
# ['2014', 'Callan', 'M', '384']
# ['2014', 'Brett', 'M', '383']
# ['2014', 'Duke', 'M', '383']
# ['2014', 'Zechariah', 'M', '383']
# ['2014', 'Bruno', 'M', '381']
# ['2014', 'Sylas', 'M', '381']
# ['2014', 'Melvin', 'M', '379']
# ['2014', 'Tripp', 'M', '378']
# ['2014', 'Julien', 'M', '377']
# ['2014', 'Branson', 'M', '376']
# ['2014', 'Blaine', 'M', '375']
# ['2014', 'Guillermo', 'M', '374']
# ['2014', 'Jon', 'M', '374']
# ['2014', 'Zain', 'M', '373']
# ['2014', 'Arian', 'M', '372']
# ['2014', 'Rayden', 'M', '371']
# ['2014', 'Brodie', 'M', '370']
# ['2014', 'Stanley', 'M', '369']
# ['2014', 'Memphis', 'M', '368']
# ['2014', 'Crew', 'M', '367']
# ['2014', 'Kelvin', 'M', '366']
# ['2014', 'Joey', 'M', '365']
# ['2014', 'Terrance', 'M', '364']
# ['2014', 'Emery', 'M', '363']
# ['2014', 'Amos', 'M', '362']
# ['2014', 'Edison', 'M', '361']
# ['2014', 'Channing', 'M', '359']
# ['2014', 'Lennon', 'M', '359']
# ['2014', 'Yosef', 'M', '359']
# ['2014', 'Demetrius', 'M', '357']
# ['2014', 'Cayson', 'M', '356']
# ['2014', 'Xzavier', 'M', '356']
# ['2014', 'Cory', 'M', '355']
# ['2014', 'Rodney', 'M', '355']
# ['2014', 'Elian', 'M', '354']
# ['2014', 'Bronson', 'M', '353']
# ['2014', 'Dayton', 'M', '351']
# ['2014', 'Bentlee', 'M', '348']
# ['2014', 'Lee', 'M', '348']
# ['2014', 'Cassius', 'M', '345']
# ['2014', 'Chad', 'M', '345']
# ['2014', 'Jagger', 'M', '343']
# ['2014', 'Fletcher', 'M', '341']
# ['2014', 'Omari', 'M', '341']
# ['2014', 'Westin', 'M', '340']
# ['2014', 'Alonso', 'M', '339']
# ['2014', 'Brenden', 'M', '339']
# ['2014', 'Makai', 'M', '339']
# ['2014', 'Felipe', 'M', '336']
# ['2014', 'Forrest', 'M', '336']
# ['2014', 'Harry', 'M', '336']
# ['2014', 'Alden', 'M', '335']
# ['2014', 'Maxim', 'M', '335']
# ['2014', 'Ben', 'M', '334']
# ['2014', 'Enoch', 'M', '334']
# ['2014', 'Nickolas', 'M', '334']
# ['2014', 'Allan', 'M', '333']
# ['2014', 'Davion', 'M', '333']
# ['2014', 'Willie', 'M', '331']
# ['2014', 'Tommy', 'M', '330']
# ['2014', 'Terrence', 'M', '329']
# ['2014', 'Cain', 'M', '328']
# ['2014', 'Harper', 'M', '328']
# ['2014', 'Kody', 'M', '328']
# ['2014', 'Adonis', 'M', '327']
# ['2014', 'Callum', 'M', '327']
# ['2014', 'Jermaine', 'M', '325']
# ['2014', 'Ray', 'M', '325']
# ['2014', 'Thaddeus', 'M', '325']
# ['2014', 'Zeke', 'M', '324']
# ['2014', 'Elisha', 'M', '323']
# ['2014', 'Kamari', 'M', '322']
# ['2014', 'Aron', 'M', '321']
# ['2014', 'Aydin', 'M', '321']
# ['2014', 'Shaun', 'M', '321']
# ['2014', 'Markus', 'M', '320']
# ['2014', 'Ariel', 'M', '319']
# ['2014', 'Lucca', 'M', '319']
# ['2014', 'Marcelo', 'M', '319']
# ['2014', 'Vicente', 'M', '319']
# ['2014', 'Keagan', 'M', '318']
# ['2014', 'Marlon', 'M', '318']
# ['2014', 'Aryan', 'M', '317']
# ['2014', 'Anders', 'M', '315']
# ['2014', 'Ulises', 'M', '315']
# ['2014', 'Langston', 'M', '314']
# ['2014', 'Kareem', 'M', '313']
# ['2014', 'Bobby', 'M', '311']
# ['2014', 'Ronnie', 'M', '311']
# ['2014', 'Will', 'M', '311']
# ['2014', 'Alexzander', 'M', '310']
# ['2014', 'Davian', 'M', '310']
# ['2014', 'Kendall', 'M', '310']
# ['2014', 'Hassan', 'M', '309']
# ['2014', 'Jadiel', 'M', '309']
# ['2014', 'Samir', 'M', '309']
# ['2014', 'Axton', 'M', '308']
# ['2014', 'Kingsley', 'M', '308']
# ['2014', 'Trace', 'M', '308']
# ['2014', 'Yousef', 'M', '307']
# ['2014', 'Valentino', 'M', '306']
# ['2014', 'Jamal', 'M', '305']
# ['2014', 'Brecken', 'M', '304']
# ['2014', 'Fisher', 'M', '303']
# ['2014', 'Giovani', 'M', '303']
# ['2014', 'Kaysen', 'M', '303']
# ['2014', 'Maxton', 'M', '301']
# ['2014', 'Mayson', 'M', '301']
# ['2014', 'Van', 'M', '300']
# ['2014', 'Hezekiah', 'M', '299']
# ['2014', 'Blaze', 'M', '298']
# ['2014', 'Javon', 'M', '298']
# ['2014', 'Kolby', 'M', '297']
# ['2014', 'Jedidiah', 'M', '296']
# ['2014', 'Kolten', 'M', '296']
# ['2014', 'Misael', 'M', '296']
# ['2014', 'Ares', 'M', '295']
# ['2014', 'Rogelio', 'M', '295']
# ['2014', 'Bode', 'M', '294']
# ['2014', 'Jamie', 'M', '294']
# ['2014', 'Leandro', 'M', '294']
# ['2014', 'Rowen', 'M', '294']
# ['2014', 'Cedric', 'M', '293']
# ['2014', 'Urijah', 'M', '293']
# ['2014', 'Eugene', 'M', '291']
# ['2014', 'Wayne', 'M', '291']
# ['2014', 'Kase', 'M', '289']
# ['2014', 'Kole', 'M', '288']
# ['2014', 'Alfred', 'M', '287']
# ['2014', 'Billy', 'M', '287']
# ['2014', 'Camron', 'M', '287']
# ['2014', 'Darian', 'M', '287']
# ['2014', 'Rene', 'M', '287']
# ['2014', 'Chaim', 'M', '286']
# ['2014', 'Duncan', 'M', '286']
# ['2014', 'Maison', 'M', '286']
# ['2014', 'Adrien', 'M', '285']
# ['2014', 'Apollo', 'M', '285']
# ['2014', 'Braeden', 'M', '285']
# ['2014', 'Reginald', 'M', '285']
# ['2014', 'Clyde', 'M', '284']
# ['2014', 'Mack', 'M', '284']
# ['2014', 'Jerome', 'M', '282']
# ['2014', 'Anson', 'M', '281']
# ['2014', 'Jessie', 'M', '281']
# ['2014', 'Ishaan', 'M', '280']
# ['2014', 'Micheal', 'M', '280']
# ['2014', 'Vincenzo', 'M', '280']
# ['2014', 'Javion', 'M', '279']
# ['2014', 'Gauge', 'M', '278']
# ['2014', 'Gerald', 'M', '278']
# ['2014', 'Camdyn', 'M', '277']
# ['2014', 'Keenan', 'M', '277']
# ['2014', 'Marley', 'M', '277']
# ['2014', 'Terrell', 'M', '276']
# ['2014', 'Draven', 'M', '275']
# ['2014', 'Junior', 'M', '275']
# ['2014', 'Franco', 'M', '274']
# ['2014', 'Jamir', 'M', '274']
# ['2014', 'Justus', 'M', '274']
# ['2014', 'Braiden', 'M', '272']
# ['2014', 'Giancarlo', 'M', '272']
# ['2014', 'Landry', 'M', '272']
# ['2014', 'Brantlee', 'M', '271']
# ['2014', 'Harold', 'M', '271']
# ['2014', 'Titan', 'M', '271']
# ['2014', 'Dilan', 'M', '270']
# ['2014', 'Joziah', 'M', '270']
# ['2014', 'Zayn', 'M', '270']
# ['2014', 'Azariah', 'M', '269']
# ['2014', 'Briggs', 'M', '269']
# ['2014', 'Kyree', 'M', '269']
# ['2014', 'Marquis', 'M', '269']
# ['2014', 'Stetson', 'M', '269']
# ['2014', 'Jonathon', 'M', '267']
# ['2014', 'Clay', 'M', '266']
# ['2014', 'Lamar', 'M', '266']
# ['2014', 'Tyrone', 'M', '266']
# ['2014', 'Axl', 'M', '264']
# ['2014', 'Kenny', 'M', '264']
# ['2014', 'Reuben', 'M', '264']
# ['2014', 'Amare', 'M', '263']
# ['2014', 'Brent', 'M', '263']
# ['2014', 'Alfonso', 'M', '262']
# ['2014', 'Blaise', 'M', '262']
# ['2014', 'Dariel', 'M', '262']
# ['2014', 'Marcel', 'M', '261']
# ['2014', 'Jaydon', 'M', '260']
# ['2014', 'Stefan', 'M', '260']
# ['2014', 'Finnley', 'M', '259']
# ['2014', 'Gibson', 'M', '259']
# ['2014', 'Jadon', 'M', '259']
# ['2014', 'Darrell', 'M', '257']
# ['2014', 'Kalel', 'M', '257']
# ['2014', 'Steve', 'M', '257']
# ['2014', 'Triston', 'M', '257']
# ['2014', 'Abdiel', 'M', '256']
# ['2014', 'Jairo', 'M', '255']
# ['2014', 'Lyric', 'M', '255']
# ['2014', 'Hugh', 'M', '254']
# ['2014', 'Rudy', 'M', '254']
# ['2014', 'Thatcher', 'M', '254']
# ['2014', 'Castiel', 'M', '253']
# ['2014', 'Emory', 'M', '253']
# ['2014', 'Henrik', 'M', '253']
# ['2014', 'Eliezer', 'M', '252']
# ['2014', 'Graysen', 'M', '252']
# ['2014', 'Konnor', 'M', '251']
# ['2014', 'Miller', 'M', '249']
# ['2014', 'Tristian', 'M', '249']
# ['2014', 'Cristiano', 'M', '247']
# ['2014', 'Deshawn', 'M', '247']
# ['2014', 'Ernest', 'M', '247']
# ['2014', 'Kamdyn', 'M', '247']
# ['2014', 'Rylee', 'M', '247']
# ['2014', 'Agustin', 'M', '246']
# ['2014', 'Zavier', 'M', '246']
# ['2014', 'Dimitri', 'M', '245']
# ['2014', 'Dwayne', 'M', '245']
# ['2014', 'Ford', 'M', '244']
# ['2014', 'Rey', 'M', '244']
# ['2014', 'Santana', 'M', '244']
# ['2014', 'Vance', 'M', '243']
# ['2014', 'Arnav', 'M', '242']
# ['2014', 'Sonny', 'M', '242']
# ['2014', 'Brice', 'M', '241']
# ['2014', 'Jamarion', 'M', '241']
# ['2014', 'Ramiro', 'M', '241']
# ['2014', 'Gilbert', 'M', '240']
# ['2014', 'Leighton', 'M', '240']
# ['2014', 'Coen', 'M', '239']
# ['2014', 'Jordyn', 'M', '239']
# ['2014', 'Kaeden', 'M', '239']
# ['2014', 'Anton', 'M', '238']
# ['2014', 'Rolando', 'M', '238']
# ['2014', 'Salvatore', 'M', '238']
# ['2014', 'Aaden', 'M', '237']
# ['2014', 'Aydan', 'M', '237']
# ['2014', 'Chevy', 'M', '237']
# ['2014', 'Seamus', 'M', '237']
# ['2014', 'Zaire', 'M', '237']
# ['2014', 'Darwin', 'M', '236']
# ['2014', 'Lachlan', 'M', '236']
# ['2014', 'Lochlan', 'M', '236']
# ['2014', 'Santos', 'M', '236']
# ['2014', 'Jayse', 'M', '235']
# ['2014', 'Mustafa', 'M', '235']
# ['2014', 'Randall', 'M', '235']
# ['2014', 'Yael', 'M', '235']
# ['2014', 'Grey', 'M', '234']
# ['2014', 'Johnathon', 'M', '234']
# ['2014', 'Kohen', 'M', '234']
# ['2014', 'Rashad', 'M', '234']
# ['2014', 'Kannon', 'M', '233']
# ['2014', 'Clinton', 'M', '232']
# ['2014', 'Konner', 'M', '232']
# ['2014', 'Jovani', 'M', '231']
# ['2014', 'Maximo', 'M', '231']
# ['2014', 'Alvaro', 'M', '230']
# ['2014', 'Jordy', 'M', '230']
# ['2014', 'Aidyn', 'M', '229']
# ['2014', 'Kymani', 'M', '229']
# ['2014', 'Davin', 'M', '228']
# ['2014', 'Ephraim', 'M', '228']
# ['2014', 'Heath', 'M', '228']
# ['2014', 'Frankie', 'M', '227']
# ['2014', 'Kamron', 'M', '227']
# ['2014', 'Craig', 'M', '226']
# ['2014', 'Houston', 'M', '226']
# ['2014', 'Vaughn', 'M', '226']
# ['2014', 'Yehuda', 'M', '226']
# ['2014', 'Rodolfo', 'M', '225']
# ['2014', 'Cristopher', 'M', '224']
# ['2014', 'Gino', 'M', '224']
# ['2014', 'Gordon', 'M', '224']
# ['2014', 'Harlan', 'M', '224']
# ['2014', 'Turner', 'M', '224']
# ['2014', 'Vivaan', 'M', '224']
# ['2014', 'Ameer', 'M', '223']
# ['2014', 'Gavyn', 'M', '223']
# ['2014', 'Jovanni', 'M', '223']
# ['2014', 'Benton', 'M', '222']
# ['2014', 'Coleman', 'M', '222']
# ['2014', 'Dash', 'M', '222']
# ['2014', 'Jaycob', 'M', '222']
# ['2014', 'Jericho', 'M', '222']
# ['2014', 'Makhi', 'M', '222']
# ['2014', 'Dominique', 'M', '221']
# ['2014', 'Zaid', 'M', '221']
# ['2014', 'Augustine', 'M', '220']
# ['2014', 'Eliseo', 'M', '220']
# ['2014', 'Emmet', 'M', '220']
# ['2014', 'Khalid', 'M', '220']
# ['2014', 'Quintin', 'M', '220']
# ['2014', 'Truman', 'M', '220']
# ['2014', 'Anakin', 'M', '219']
# ['2014', 'Camren', 'M', '219']
# ['2014', 'Judson', 'M', '219']
# ['2014', 'Baylor', 'M', '218']
# ['2014', 'Efrain', 'M', '218']
# ['2014', 'Semaj', 'M', '218']
# ['2014', 'Camilo', 'M', '217']
# ['2014', 'Damari', 'M', '217']
# ['2014', 'Giovanny', 'M', '216']
# ['2014', 'Kale', 'M', '216']
# ['2014', 'Kamryn', 'M', '216']
# ['2014', 'Broderick', 'M', '215']
# ['2014', 'Deangelo', 'M', '215']
# ['2014', 'Koen', 'M', '215']
# ['2014', 'Magnus', 'M', '215']
# ['2014', 'Mike', 'M', '215']
# ['2014', 'Bodie', 'M', '214']
# ['2014', 'Dario', 'M', '214']
# ['2014', 'Brayson', 'M', '213']
# ['2014', 'Chace', 'M', '213']
# ['2014', 'Jayvion', 'M', '213']
# ['2014', 'Kaison', 'M', '213']
# ['2014', 'Darien', 'M', '212']
# ['2014', 'Teagan', 'M', '212']
# ['2014', 'Valentin', 'M', '212']
# ['2014', 'Bridger', 'M', '211']
# ['2014', 'Menachem', 'M', '211']
# ['2014', 'Kylen', 'M', '210']
# ['2014', 'Rocky', 'M', '210']
# ['2014', 'Boden', 'M', '209']
# ['2014', 'Foster', 'M', '209']
# ['2014', 'Howard', 'M', '209']
# ['2014', 'Maddux', 'M', '209']
# ['2014', 'Jair', 'M', '208']
# ['2014', 'Osvaldo', 'M', '208']
# ['2014', 'Ayan', 'M', '207']
# ['2014', 'Ean', 'M', '207']
# ['2014', 'Reyansh', 'M', '207']
# ['2014', 'Tyree', 'M', '207']
# ['2014', 'Garrison', 'M', '206']
# ['2014', 'Rylen', 'M', '206']
# ['2014', 'Sutton', 'M', '206']
# ['2014', 'Demarcus', 'M', '205']
# ['2014', 'Leif', 'M', '205']
# ['2014', 'Reagan', 'M', '205']
# ['2014', 'Carsen', 'M', '204']
# ['2014', 'Musa', 'M', '204']
# ['2014', 'Branden', 'M', '203']
# ['2014', 'Otis', 'M', '203']
# ['2014', 'Pierre', 'M', '203']
# ['2014', 'Gerard', 'M', '202']
# ['2014', 'Immanuel', 'M', '202']
# ['2014', 'Abner', 'M', '201']
# ['2014', 'Tyrell', 'M', '201']
# ['2014', 'Briar', 'M', '200']
# ['2014', 'Freddy', 'M', '200']
# ['2014', 'Jamar', 'M', '200']
# ['2014', 'Braylin', 'M', '199']
# ['2014', 'Brogan', 'M', '199']
# ['2014', 'Gilberto', 'M', '199']
# ['2014', 'Jakobe', 'M', '199']
# ['2014', 'Brenton', 'M', '198']
# ['2014', 'Jai', 'M', '198']
# ['2014', 'Yisroel', 'M', '198']
# ['2014', 'Harlem', 'M', '197']
# ['2014', 'Jaylin', 'M', '197']
# ['2014', 'Korbyn', 'M', '197']
# ['2014', 'Brysen', 'M', '196']
# ['2014', 'Clarence', 'M', '196']
# ['2014', 'Cormac', 'M', '196']
# ['2014', 'Dangelo', 'M', '196']
# ['2014', 'Darnell', 'M', '196']
# ['2014', 'Boone', 'M', '195']
# ['2014', 'Cortez', 'M', '195']
# ['2014', 'Deon', 'M', '195']
# ['2014', 'Krish', 'M', '195']
# ['2014', 'Merrick', 'M', '195']
# ['2014', 'Karsen', 'M', '194']
# ['2014', 'Antoine', 'M', '193']
# ['2014', 'Jarrett', 'M', '193']
# ['2014', 'Jorden', 'M', '193']
# ['2014', 'Ralph', 'M', '193']
# ['2014', 'Octavio', 'M', '192']
# ['2014', 'Shiloh', 'M', '192']
# ['2014', 'Eliot', 'M', '191']
# ['2014', 'Tristin', 'M', '191']
# ['2014', 'Aayden', 'M', '190']
# ['2014', 'Aditya', 'M', '190']
# ['2014', 'Derick', 'M', '190']
# ['2014', 'Robin', 'M', '190']
# ['2014', 'Bishop', 'M', '189']
# ['2014', 'Kaidyn', 'M', '189']
# ['2014', 'Kenton', 'M', '188']
# ['2014', 'Tadeo', 'M', '188']
# ['2014', 'Avi', 'M', '187']
# ['2014', 'Denver', 'M', '187']
# ['2014', 'Kamren', 'M', '187']
# ['2014', 'Leroy', 'M', '187']
# ['2014', 'Elvis', 'M', '186']
# ['2014', 'Isiah', 'M', '186']
# ['2014', 'Maxx', 'M', '186']
# ['2014', 'Rayyan', 'M', '186']
# ['2014', 'Camryn', 'M', '184']
# ['2014', 'Graeme', 'M', '184']
# ['2014', 'Jean', 'M', '184']
# ['2014', 'Ross', 'M', '184']
# ['2014', 'Denzel', 'M', '183']
# ['2014', 'Mordechai', 'M', '182']
# ['2014', 'Aarush', 'M', '181']
# ['2014', 'Brendon', 'M', '180']
# ['2014', 'Dale', 'M', '180']
# ['2014', 'Damarion', 'M', '180']
# ['2014', 'Decker', 'M', '180']
# ['2014', 'Izayah', 'M', '180']
# ['2014', 'Juelz', 'M', '180']
# ['2014', 'Masen', 'M', '180']
# ['2014', 'Todd', 'M', '180']
# ['2014', 'Canaan', 'M', '179']
# ['2014', 'Karim', 'M', '179']
# ['2014', 'Yadiel', 'M', '179']
# ['2014', 'Alistair', 'M', '178']
# ['2014', 'Carlo', 'M', '178']
# ['2014', 'Darryl', 'M', '178']
# ['2014', 'Kooper', 'M', '178']
# ['2014', 'Ledger', 'M', '178']
# ['2014', 'Roderick', 'M', '178']
# ['2014', 'Lathan', 'M', '177']
# ['2014', 'Stone', 'M', '177']
# ['2014', 'Harris', 'M', '176']
# ['2014', 'Mariano', 'M', '176']
# ['2014', 'Slade', 'M', '176']
# ['2014', 'Cale', 'M', '175']
# ['2014', 'Edmund', 'M', '175']
# ['2014', 'Milton', 'M', '175']
# ['2014', 'Ignacio', 'M', '174']
# ['2014', 'Simeon', 'M', '174']
# ['2014', 'Westley', 'M', '174']
# ['2014', 'Yair', 'M', '174']
# ['2014', 'Youssef', 'M', '174']
# ['2014', 'Campbell', 'M', '173']
# ['2014', 'Kye', 'M', '173']
# ['2014', 'Nikhil', 'M', '173']
# ['2014', 'Ulysses', 'M', '173']
# ['2014', 'Yandel', 'M', '173']
# ['2014', 'Cael', 'M', '172']
# ['2014', 'Cairo', 'M', '172']
# ['2014', 'Deklan', 'M', '172']
# ['2014', 'Jaxx', 'M', '172']
# ['2014', 'Jaylon', 'M', '172']
# ['2014', 'Louie', 'M', '172']
# ['2014', 'Lyle', 'M', '172']
# ['2014', 'Trystan', 'M', '172']
# ['2014', 'Zahir', 'M', '172']
# ['2014', 'Damion', 'M', '171']
# ['2014', 'Eason', 'M', '171']
# ['2014', 'Aedan', 'M', '170']
# ['2014', 'Humberto', 'M', '170']
# ['2014', 'Jovan', 'M', '170']
# ['2014', 'Kashton', 'M', '170']
# ['2014', 'Keller', 'M', '170']
# ['2014', 'Malaki', 'M', '170']
# ['2014', 'Norman', 'M', '170']
# ['2014', 'Zyaire', 'M', '170']
# ['2014', 'Achilles', 'M', '169']
# ['2014', 'Aleksander', 'M', '169']
# ['2014', 'Imran', 'M', '169']
# ['2014', 'Jeremias', 'M', '169']
# ['2014', 'Keon', 'M', '169']
# ['2014', 'Davon', 'M', '168']
# ['2014', 'Isai', 'M', '168']
# ['2014', 'Jaxxon', 'M', '168']
# ['2014', 'Shimon', 'M', '168']
# ['2014', 'Xavi', 'M', '168']
# ['2014', 'Corban', 'M', '167']
# ['2014', 'Dhruv', 'M', '167']
# ['2014', 'Elmer', 'M', '167']
# ['2014', 'Ridge', 'M', '167']
# ['2014', 'Sidney', 'M', '167']
# ['2014', 'Bradyn', 'M', '166']
# ['2014', 'Jabari', 'M', '166']
# ['2014', 'Johnpaul', 'M', '166']
# ['2014', 'Vladimir', 'M', '166']
# ['2014', 'Yahya', 'M', '166']
# ['2014', 'Marcello', 'M', '165']
# ['2014', 'Sheldon', 'M', '165']
# ['2014', 'Shlomo', 'M', '165']
# ['2014', 'Torin', 'M', '165']
# ['2014', 'Deegan', 'M', '164']
# ['2014', 'Donte', 'M', '164']
# ['2014', 'Fox', 'M', '164']
# ['2014', 'Josh', 'M', '164']
# ['2014', 'Shmuel', 'M', '164']
# ['2014', 'Zayd', 'M', '164']
# ['2014', 'Dion', 'M', '163']
# ['2014', 'Jaceon', 'M', '163']
# ['2014', 'Linus', 'M', '163']
# ['2014', 'Mac', 'M', '163']
# ['2014', 'Alton', 'M', '162']
# ['2014', 'Aries', 'M', '162']
# ['2014', 'Colter', 'M', '162']
# ['2014', 'Koda', 'M', '162']
# ['2014', 'Mikel', 'M', '162']
# ['2014', 'Shepherd', 'M', '162']
# ['2014', 'Aston', 'M', '161']
# ['2014', 'German', 'M', '161']
# ['2014', 'Haiden', 'M', '161']
# ['2014', 'Ronaldo', 'M', '161']
# ['2014', 'Viktor', 'M', '161']
# ['2014', 'Ira', 'M', '160']
# ['2014', 'Karl', 'M', '160']
# ['2014', 'Coby', 'M', '159']
# ['2014', 'Glenn', 'M', '159']
# ['2014', 'Yaakov', 'M', '159']
# ['2014', 'Ewan', 'M', '158']
# ['2014', 'Gianluca', 'M', '158']
# ['2014', 'Jaeden', 'M', '158']
# ['2014', 'Kael', 'M', '158']
# ['2014', 'Kallen', 'M', '158']
# ['2014', 'Wesson', 'M', '158']
# ['2014', 'Bernard', 'M', '157']
# ['2014', 'Gatlin', 'M', '157']
# ['2014', 'Haven', 'M', '157']
# ['2014', 'Kennedy', 'M', '157']
# ['2014', 'Stephan', 'M', '157']
# ['2014', 'Greysen', 'M', '156']
# ['2014', 'Guy', 'M', '156']
# ['2014', 'Nick', 'M', '156']
# ['2014', 'Amar', 'M', '155']
# ['2014', 'Carmine', 'M', '155']
# ['2014', 'Gus', 'M', '155']
# ['2014', 'Ruger', 'M', '155']
# ['2014', 'Bently', 'M', '154']
# ['2014', 'Diesel', 'M', '154']
# ['2014', 'Kelton', 'M', '154']
# ['2014', 'Tobin', 'M', '154']
# ['2014', 'Alaric', 'M', '153']
# ['2014', 'Brighton', 'M', '153']
# ['2014', 'Brixton', 'M', '153']
# ['2014', 'Corbyn', 'M', '153']
# ['2014', 'Jarvis', 'M', '153']
# ['2014', 'Mccoy', 'M', '153']
# ['2014', 'Nigel', 'M', '153']
# ['2014', 'Tayden', 'M', '153']
# ['2014', 'Zev', 'M', '153']
# ['2014', 'Armaan', 'M', '152']
# ['2014', 'Avraham', 'M', '152']
# ['2014', 'Brennen', 'M', '152']
# ['2014', 'Cian', 'M', '152']
# ['2014', 'Cornelius', 'M', '152']
# ['2014', 'Emir', 'M', '152']
# ['2014', 'Kain', 'M', '152']
# ['2014', 'Vince', 'M', '152']
# ['2014', 'Coy', 'M', '151']
# ['2014', 'Daylen', 'M', '150']
# ['2014', 'Devan', 'M', '150']
# ['2014', 'Jaziel', 'M', '150']
# ['2014', 'Jionni', 'M', '150']
# ['2014', 'Joan', 'M', '150']
# ['2014', 'Kyren', 'M', '150']
# ['2014', 'Lucien', 'M', '150']
# ['2014', 'Mikael', 'M', '150']
# ['2014', 'Rico', 'M', '150']
# ['2014', 'Bilal', 'M', '149']
# ['2014', 'Dereck', 'M', '149']
# ['2014', 'Perry', 'M', '149']
# ['2014', 'Jacobi', 'M', '148']
# ['2014', 'Kent', 'M', '148']
# ['2014', 'Kruz', 'M', '148']
# ['2014', 'Pranav', 'M', '148']
# ['2014', 'Raheem', 'M', '148']
# ['2014', 'Zamir', 'M', '148']
# ['2014', 'Gonzalo', 'M', '147']
# ['2014', 'Idris', 'M', '147']
# ['2014', 'Jacen', 'M', '147']
# ['2014', 'Josias', 'M', '147']
# ['2014', 'Kiyan', 'M', '147']
# ['2014', 'Meir', 'M', '147']
# ['2014', 'Sami', 'M', '147']
# ['2014', 'Jaydan', 'M', '146']
# ['2014', 'Jesiah', 'M', '146']
# ['2014', 'Jordi', 'M', '146']
# ['2014', 'Lyndon', 'M', '146']
# ['2014', 'Tevin', 'M', '146']
# ['2014', 'Adler', 'M', '145']
# ['2014', 'Baron', 'M', '145']
# ['2014', 'Gaige', 'M', '145']
# ['2014', 'Nikko', 'M', '144']
# ['2014', 'Yaseen', 'M', '144']
# ['2014', 'Yeshua', 'M', '144']
# ['2014', 'Cristobal', 'M', '143']
# ['2014', 'Francesco', 'M', '143']
# ['2014', 'Jaidyn', 'M', '143']
# ['2014', 'Sammy', 'M', '143']
# ['2014', 'Siddharth', 'M', '143']
# ['2014', 'Amarion', 'M', '142']
# ['2014', 'Colson', 'M', '142']
# ['2014', 'Irvin', 'M', '142']
# ['2014', 'Presley', 'M', '142']
# ['2014', 'Taj', 'M', '142']
# ['2014', 'Tiago', 'M', '142']
# ['2014', 'Dillan', 'M', '141']
# ['2014', 'Jad', 'M', '141']
# ['2014', 'Kasey', 'M', '141']
# ['2014', 'Keanu', 'M', '141']
# ['2014', 'Kyron', 'M', '141']
# ['2014', 'Deven', 'M', '140']
# ['2014', 'Fredrick', 'M', '140']
# ['2014', 'Geovanni', 'M', '140']
# ['2014', 'Jaxsen', 'M', '140']
# ['2014', 'Zackery', 'M', '140']
# ['2014', 'Zaden', 'M', '140']
# ['2014', 'Aayan', 'M', '139']
# ['2014', 'Devyn', 'M', '139']
# ['2014', 'Eddy', 'M', '139']
# ['2014', 'Ever', 'M', '139']
# ['2014', 'Ishmael', 'M', '139']
# ['2014', 'Reynaldo', 'M', '139']
# ['2014', 'Syed', 'M', '139']
# ['2014', 'Benny', 'M', '138']
# ['2014', 'Creed', 'M', '138']
# ['2014', 'Estevan', 'M', '138']
# ['2014', 'Jet', 'M', '138']
# ['2014', 'Smith', 'M', '138']
# ['2014', 'Tyrese', 'M', '138']
# ['2014', 'Wallace', 'M', '138']
# ['2014', 'Zack', 'M', '138']
# ['2014', 'Adolfo', 'M', '137']
# ['2014', 'Antwan', 'M', '137']
# ['2014', 'Benedict', 'M', '137']
# ['2014', 'Daryl', 'M', '137']
# ['2014', 'Kyan', 'M', '137']
# ['2014', 'Micaiah', 'M', '137']
# ['2014', 'Mikhail', 'M', '137']
# ['2014', 'Pierson', 'M', '137']
# ['2014', 'Rowdy', 'M', '137']
# ['2014', 'Zaylen', 'M', '137']
# ['2014', 'Ahmir', 'M', '136']
# ['2014', 'Cashton', 'M', '136']
# ['2014', 'Eamon', 'M', '136']
# ['2014', 'Ismail', 'M', '136']
# ['2014', 'Kadyn', 'M', '136']
# ['2014', 'Rigoberto', 'M', '136']
# ['2014', 'Jaron', 'M', '135']
# ['2014', 'Laith', 'M', '135']
# ['2014', 'Lamont', 'M', '135']
# ['2014', 'Quinten', 'M', '135']
# ['2014', 'Alexandro', 'M', '134']
# ['2014', 'Aubrey', 'M', '134']
# ['2014', 'Bryden', 'M', '134']
# ['2014', 'Austyn', 'M', '133']
# ['2014', 'Bailey', 'M', '133']
# ['2014', 'Ethen', 'M', '133']
# ['2014', 'Hans', 'M', '133']
# ['2014', 'Isaak', 'M', '133']
# ['2014', 'Jaquan', 'M', '133']
# ['2014', 'Kace', 'M', '133']
# ['2014', 'Keyon', 'M', '133']
# ['2014', 'Oskar', 'M', '133']
# ['2014', 'Sebastien', 'M', '133']
# ['2014', 'Courtney', 'M', '132']
# ['2014', 'Elvin', 'M', '132']
# ['2014', 'Keelan', 'M', '132']
# ['2014', 'Leeland', 'M', '132']
# ['2014', 'Marquise', 'M', '132']
# ['2014', 'Wilder', 'M', '132']
# ['2014', 'Andreas', 'M', '131']
# ['2014', 'Bear', 'M', '131']
# ['2014', 'Leyton', 'M', '131']
# ['2014', 'Maksim', 'M', '131']
# ['2014', 'Addison', 'M', '130']
# ['2014', 'Ajay', 'M', '130']
# ['2014', 'Atreyu', 'M', '130']
# ['2014', 'Deion', 'M', '130']
# ['2014', 'Destin', 'M', '130']
# ['2014', 'Forest', 'M', '130']
# ['2014', 'Izaac', 'M', '130']
# ['2014', 'Johann', 'M', '130']
# ['2014', 'Rian', 'M', '130']
# ['2014', 'Bronx', 'M', '129']
# ['2014', 'Cal', 'M', '129']
# ['2014', 'Dwight', 'M', '129']
# ['2014', 'Elan', 'M', '129']
# ['2014', 'Noble', 'M', '129']
# ['2014', 'Benicio', 'M', '128']
# ['2014', 'Eliel', 'M', '128']
# ['2014', 'Tahj', 'M', '128']
# ['2014', 'Yitzchok', 'M', '128']
# ['2014', 'Brandt', 'M', '127']
# ['2014', 'Devonte', 'M', '127']
# ['2014', 'Gray', 'M', '127']
# ['2014', 'Korben', 'M', '127']
# ['2014', 'Canon', 'M', '126']
# ['2014', 'Donnie', 'M', '126']
# ['2014', 'Hansel', 'M', '126']
# ['2014', 'Huxley', 'M', '126']
# ['2014', 'Marcellus', 'M', '126']
# ['2014', 'Mikah', 'M', '126']
# ['2014', 'Austen', 'M', '125']
# ['2014', 'Avion', 'M', '125']
# ['2014', 'Bastian', 'M', '125']
# ['2014', 'Caysen', 'M', '125']
# ['2014', 'Dashiell', 'M', '125']
# ['2014', 'Giuseppe', 'M', '125']
# ['2014', 'Hollis', 'M', '125']
# ['2014', 'Kabir', 'M', '125']
# ['2014', 'Rome', 'M', '125']
# ['2014', 'Zachery', 'M', '125']
# ['2014', 'Aksel', 'M', '124']
# ['2014', 'Alek', 'M', '124']
# ['2014', 'Caius', 'M', '124']
# ['2014', 'Eleazar', 'M', '124']
# ['2014', 'Faris', 'M', '124']
# ['2014', 'Finnian', 'M', '124']
# ['2014', 'Hagen', 'M', '124']
# ['2014', 'Jael', 'M', '124']
# ['2014', 'Jaycion', 'M', '124']
# ['2014', 'Lazarus', 'M', '124']
# ['2014', 'Tzvi', 'M', '124']
# ['2014', 'Westyn', 'M', '124']
# ['2014', 'Zavion', 'M', '124']
# ['2014', 'Dashawn', 'M', '123']
# ['2014', 'Jariel', 'M', '123']
# ['2014', 'Maddex', 'M', '123']
# ['2014', 'Zephaniah', 'M', '123']
# ['2014', 'Abdirahman', 'M', '122']
# ['2014', 'Abdulrahman', 'M', '122']
# ['2014', 'Barry', 'M', '122']
# ['2014', 'Gian', 'M', '122']
# ['2014', 'Kyran', 'M', '122']
# ['2014', 'Lucius', 'M', '122']
# ['2014', 'Murphy', 'M', '122']
# ['2014', 'Sky', 'M', '122']
# ['2014', 'Wes', 'M', '122']
# ['2014', 'Aven', 'M', '121']
# ['2014', 'Beck', 'M', '121']
# ['2014', 'Brently', 'M', '121']
# ['2014', 'Carver', 'M', '121']
# ['2014', 'Hasan', 'M', '121']
# ['2014', 'Ammar', 'M', '120']
# ['2014', 'Eliyahu', 'M', '120']
# ['2014', 'Ender', 'M', '120']
# ['2014', 'Neal', 'M', '120']
# ['2014', 'Nikola', 'M', '120']
# ['2014', 'Vernon', 'M', '120']
# ['2014', 'Clifford', 'M', '119']
# ['2014', 'Cordell', 'M', '119']
# ['2014', 'Demarion', 'M', '119']
# ['2014', 'Emil', 'M', '119']
# ['2014', 'Gionni', 'M', '119']
# ['2014', 'Jenson', 'M', '119']
# ['2014', 'Khai', 'M', '119']
# ['2014', 'Lian', 'M', '119']
# ['2014', 'Lloyd', 'M', '119']
# ['2014', 'Lonnie', 'M', '119']
# ['2014', 'Tylan', 'M', '119']
# ['2014', 'Wiley', 'M', '119']
# ['2014', 'Yoel', 'M', '119']
# ['2014', 'Antony', 'M', '118']
# ['2014', 'Braedyn', 'M', '118']
# ['2014', 'Clifton', 'M', '118']
# ['2014', 'Dezmond', 'M', '118']
# ['2014', 'Domenic', 'M', '118']
# ['2014', 'Emmit', 'M', '118']
# ['2014', 'Monroe', 'M', '118']
# ['2014', 'Alexavier', 'M', '117']
# ['2014', 'Braxtyn', 'M', '117']
# ['2014', 'Eder', 'M', '117']
# ['2014', 'Johnnie', 'M', '117']
# ['2014', 'Kalvin', 'M', '117']
# ['2014', 'Kayleb', 'M', '117']
# ['2014', 'Savion', 'M', '117']
# ['2014', 'Aamir', 'M', '116']
# ['2014', 'Boaz', 'M', '116']
# ['2014', 'Kenyon', 'M', '116']
# ['2014', 'Kolt', 'M', '116']
# ['2014', 'Damani', 'M', '115']
# ['2014', 'Gentry', 'M', '115']
# ['2014', 'Hussein', 'M', '115']
# ['2014', 'Kyrin', 'M', '115']
# ['2014', 'Thor', 'M', '115']
# ['2014', 'Chaz', 'M', '114']
# ['2014', 'Danilo', 'M', '114']
# ['2014', 'Rishi', 'M', '114']
# ['2014', 'Thorin', 'M', '114']
# ['2014', 'Tyce', 'M', '114']
# ['2014', 'Dev', 'M', '113']
# ['2014', 'Irving', 'M', '113']
# ['2014', 'Jakari', 'M', '113']
# ['2014', 'Jaysen', 'M', '113']
# ['2014', 'Josef', 'M', '113']
# ['2014', 'Kurt', 'M', '113']
# ['2014', 'Massimo', 'M', '113']
# ['2014', 'Zyon', 'M', '113']
# ['2014', 'Constantine', 'M', '112']
# ['2014', 'Don', 'M', '112']
# ['2014', 'Jahmir', 'M', '112']
# ['2014', 'Jones', 'M', '112']
# ['2014', 'Mauro', 'M', '112']
# ['2014', 'Raleigh', 'M', '112']
# ['2014', 'Anas', 'M', '111']
# ['2014', 'Ansh', 'M', '111']
# ['2014', 'Jordon', 'M', '111']
# ['2014', 'Koa', 'M', '111']
# ['2014', 'Loki', 'M', '111']
# ['2014', 'Morris', 'M', '111']
# ['2014', 'Myron', 'M', '111']
# ['2014', 'Palmer', 'M', '111']
# ['2014', 'Terence', 'M', '111']
# ['2014', 'Zayvion', 'M', '111']
# ['2014', 'Arman', 'M', '110']
# ['2014', 'Damir', 'M', '110']
# ['2014', 'Fred', 'M', '110']
# ['2014', 'Jaiceon', 'M', '110']
# ['2014', 'Jeramiah', 'M', '110']
# ['2014', 'Karsyn', 'M', '110']
# ['2014', 'Kellin', 'M', '110']
# ['2014', 'Kenan', 'M', '110']
# ['2014', 'Lev', 'M', '110']
# ['2014', 'Miguelangel', 'M', '110']
# ['2014', 'Ryley', 'M', '110']
# ['2014', 'Veer', 'M', '110']
# ['2014', 'Ansel', 'M', '109']
# ['2014', 'Archie', 'M', '109']
# ['2014', 'Axle', 'M', '109']
# ['2014', 'Brigham', 'M', '109']
# ['2014', 'Ervin', 'M', '109']
# ['2014', 'Jencarlos', 'M', '109']
# ['2014', 'Kaine', 'M', '109']
# ['2014', 'Marek', 'M', '109']
# ['2014', 'Trevon', 'M', '109']
# ['2014', 'Bernardo', 'M', '108']
# ['2014', 'Dewayne', 'M', '108']
# ['2014', 'Jaleel', 'M', '108']
# ['2014', 'Jamil', 'M', '108']
# ['2014', 'Jayveon', 'M', '108']
# ['2014', 'Jiovanni', 'M', '108']
# ['2014', 'Landin', 'M', '108']
# ['2014', 'Nestor', 'M', '108']
# ['2014', 'Niam', 'M', '108']
# ['2014', 'Salem', 'M', '108']
# ['2014', 'Salman', 'M', '108']
# ['2014', 'Viaan', 'M', '108']
# ['2014', 'Angus', 'M', '107']
# ['2014', 'Ishan', 'M', '107']
# ['2014', 'Jakai', 'M', '107']
# ['2014', 'Jamarcus', 'M', '107']
# ['2014', 'Anish', 'M', '106']
# ['2014', 'Canyon', 'M', '106']
# ['2014', 'Carmello', 'M', '106']
# ['2014', 'Dakari', 'M', '106']
# ['2014', 'Damoni', 'M', '106']
# ['2014', 'Markell', 'M', '106']
# ['2014', 'Muhammed', 'M', '106']
# ['2014', 'Nazir', 'M', '106']
# ['2014', 'Phineas', 'M', '106']
# ['2014', 'Rickey', 'M', '106']
# ['2014', 'Shea', 'M', '106']
# ['2014', 'Taha', 'M', '106']
# ['2014', 'Trayvon', 'M', '106']
# ['2014', 'Zaidyn', 'M', '106']
# ['2014', 'Glen', 'M', '105']
# ['2014', 'Izaak', 'M', '105']
# ['2014', 'Kylar', 'M', '105']
# ['2014', 'Lester', 'M', '105']
# ['2014', 'Maddix', 'M', '105']
# ['2014', 'Malakhi', 'M', '105']
# ['2014', 'Talan', 'M', '105']
# ['2014', 'Yariel', 'M', '105']
# ['2014', 'Yasin', 'M', '105']
# ['2014', 'Aaryan', 'M', '104']
# ['2014', 'Azael', 'M', '104']
# ['2014', 'Britton', 'M', '104']
# ['2014', 'Earl', 'M', '104']
# ['2014', 'Kamarion', 'M', '104']
# ['2014', 'Kelly', 'M', '104']
# ['2014', 'Kyden', 'M', '104']
# ['2014', 'Levon', 'M', '104']
# ['2014', 'Nate', 'M', '104']
# ['2014', 'Nova', 'M', '104']
# ['2014', 'Raylen', 'M', '104']
# ['2014', 'Reilly', 'M', '104']
# ['2014', 'Said', 'M', '104']
# ['2014', 'Stryker', 'M', '104']
# ['2014', 'Zakariya', 'M', '104']
# ['2014', 'Abdul', 'M', '103']
# ['2014', 'Abdullahi', 'M', '103']
# ['2014', 'Ander', 'M', '103']
# ['2014', 'Ely', 'M', '103']
# ['2014', 'Jamel', 'M', '103']
# ['2014', 'Jasen', 'M', '103']
# ['2014', 'Jethro', 'M', '103']
# ['2014', 'Kirk', 'M', '103']
# ['2014', 'Montgomery', 'M', '103']
# ['2014', 'Rio', 'M', '103']
# ['2014', 'Syncere', 'M', '103']
# ['2014', 'Denis', 'M', '102']
# ['2014', 'Gareth', 'M', '102']
# ['2014', 'Jaceyon', 'M', '102']
# ['2014', 'Jerimiah', 'M', '102']
# ['2014', 'Jessiah', 'M', '102']
# ['2014', 'Zakaria', 'M', '102']
# ['2014', 'Athan', 'M', '101']
# ['2014', 'Dan', 'M', '101']
# ['2014', 'Fischer', 'M', '101']
# ['2014', 'Maxon', 'M', '101']
# ['2014', 'Noam', 'M', '101']
# ['2014', 'Rishaan', 'M', '101']
# ['2014', 'Stephon', 'M', '101']
# ['2014', 'Ammon', 'M', '100']
# ['2014', 'Cartier', 'M', '100']
# ['2014', 'Duane', 'M', '100']
# ['2014', 'Elam', 'M', '100']
# ['2014', 'Hadi', 'M', '100']
# ['2014', 'Hiram', 'M', '100']
# ['2014', 'Khaled', 'M', '100']
# ['2014', 'Shamar', 'M', '100']
# ['2014', 'Zephyr', 'M', '100']
# ['2015', 'Emma', 'F', '20355']
# ['2015', 'Olivia', 'F', '19553']
# ['2015', 'Sophia', 'F', '17327']
# ['2015', 'Ava', 'F', '16286']
# ['2015', 'Isabella', 'F', '15504']
# ['2015', 'Mia', 'F', '14820']
# ['2015', 'Abigail', 'F', '12311']
# ['2015', 'Emily', 'F', '11727']
# ['2015', 'Charlotte', 'F', '11332']
# ['2015', 'Harper', 'F', '10241']
# ['2015', 'Madison', 'F', '10038']
# ['2015', 'Amelia', 'F', '9795']
# ['2015', 'Elizabeth', 'F', '9656']
# ['2015', 'Sofia', 'F', '9650']
# ['2015', 'Evelyn', 'F', '9313']
# ['2015', 'Avery', 'F', '9298']
# ['2015', 'Chloe', 'F', '7884']
# ['2015', 'Ella', 'F', '7852']
# ['2015', 'Grace', 'F', '7589']
# ['2015', 'Victoria', 'F', '7575']
# ['2015', 'Aubrey', 'F', '7357']
# ['2015', 'Scarlett', 'F', '7100']
# ['2015', 'Zoey', 'F', '6900']
# ['2015', 'Addison', 'F', '6683']
# ['2015', 'Lily', 'F', '6617']
# ['2015', 'Lillian', 'F', '6571']
# ['2015', 'Natalie', 'F', '6466']
# ['2015', 'Hannah', 'F', '6372']
# ['2015', 'Aria', 'F', '6371']
# ['2015', 'Layla', 'F', '6289']
# ['2015', 'Brooklyn', 'F', '6268']
# ['2015', 'Alexa', 'F', '6029']
# ['2015', 'Zoe', 'F', '5995']
# ['2015', 'Penelope', 'F', '5921']
# ['2015', 'Riley', 'F', '5707']
# ['2015', 'Leah', 'F', '5585']
# ['2015', 'Audrey', 'F', '5581']
# ['2015', 'Savannah', 'F', '5413']
# ['2015', 'Allison', 'F', '5329']
# ['2015', 'Samantha', 'F', '5304']
# ['2015', 'Nora', 'F', '5301']
# ['2015', 'Skylar', 'F', '5258']
# ['2015', 'Camila', 'F', '5257']
# ['2015', 'Anna', 'F', '5094']
# ['2015', 'Paisley', 'F', '5056']
# ['2015', 'Ariana', 'F', '4933']
# ['2015', 'Ellie', 'F', '4838']
# ['2015', 'Aaliyah', 'F', '4836']
# ['2015', 'Claire', 'F', '4805']
# ['2015', 'Violet', 'F', '4779']
# ['2015', 'Stella', 'F', '4769']
# ['2015', 'Sadie', 'F', '4731']
# ['2015', 'Mila', 'F', '4712']
# ['2015', 'Gabriella', 'F', '4579']
# ['2015', 'Lucy', 'F', '4512']
# ['2015', 'Arianna', 'F', '4498']
# ['2015', 'Kennedy', 'F', '4496']
# ['2015', 'Sarah', 'F', '4476']
# ['2015', 'Madelyn', 'F', '4467']
# ['2015', 'Eleanor', 'F', '4402']
# ['2015', 'Kaylee', 'F', '4346']
# ['2015', 'Caroline', 'F', '4304']
# ['2015', 'Hazel', 'F', '4270']
# ['2015', 'Hailey', 'F', '4221']
# ['2015', 'Genesis', 'F', '4148']
# ['2015', 'Kylie', 'F', '4142']
# ['2015', 'Autumn', 'F', '4101']
# ['2015', 'Piper', 'F', '4100']
# ['2015', 'Maya', 'F', '4099']
# ['2015', 'Nevaeh', 'F', '3968']
# ['2015', 'Serenity', 'F', '3943']
# ['2015', 'Peyton', 'F', '3888']
# ['2015', 'Mackenzie', 'F', '3838']
# ['2015', 'Bella', 'F', '3760']
# ['2015', 'Eva', 'F', '3735']
# ['2015', 'Taylor', 'F', '3732']
# ['2015', 'Naomi', 'F', '3731']
# ['2015', 'Aubree', 'F', '3617']
# ['2015', 'Aurora', 'F', '3613']
# ['2015', 'Melanie', 'F', '3482']
# ['2015', 'Lydia', 'F', '3474']
# ['2015', 'Brianna', 'F', '3459']
# ['2015', 'Ruby', 'F', '3433']
# ['2015', 'Katherine', 'F', '3429']
# ['2015', 'Ashley', 'F', '3409']
# ['2015', 'Alexis', 'F', '3395']
# ['2015', 'Alice', 'F', '3395']
# ['2015', 'Cora', 'F', '3378']
# ['2015', 'Julia', 'F', '3347']
# ['2015', 'Madeline', 'F', '3305']
# ['2015', 'Faith', 'F', '3288']
# ['2015', 'Annabelle', 'F', '3250']
# ['2015', 'Alyssa', 'F', '3233']
# ['2015', 'Isabelle', 'F', '3198']
# ['2015', 'Vivian', 'F', '3183']
# ['2015', 'Gianna', 'F', '3161']
# ['2015', 'Quinn', 'F', '3077']
# ['2015', 'Clara', 'F', '3049']
# ['2015', 'Reagan', 'F', '3038']
# ['2015', 'Khloe', 'F', '2985']
# ['2015', 'Alexandra', 'F', '2983']
# ['2015', 'Hadley', 'F', '2957']
# ['2015', 'Eliana', 'F', '2956']
# ['2015', 'Sophie', 'F', '2918']
# ['2015', 'London', 'F', '2904']
# ['2015', 'Elena', 'F', '2877']
# ['2015', 'Kimberly', 'F', '2826']
# ['2015', 'Bailey', 'F', '2818']
# ['2015', 'Maria', 'F', '2803']
# ['2015', 'Luna', 'F', '2790']
# ['2015', 'Willow', 'F', '2776']
# ['2015', 'Jasmine', 'F', '2774']
# ['2015', 'Kinsley', 'F', '2762']
# ['2015', 'Valentina', 'F', '2738']
# ['2015', 'Kayla', 'F', '2718']
# ['2015', 'Delilah', 'F', '2706']
# ['2015', 'Andrea', 'F', '2699']
# ['2015', 'Natalia', 'F', '2686']
# ['2015', 'Lauren', 'F', '2677']
# ['2015', 'Morgan', 'F', '2670']
# ['2015', 'Rylee', 'F', '2668']
# ['2015', 'Sydney', 'F', '2647']
# ['2015', 'Adalynn', 'F', '2612']
# ['2015', 'Mary', 'F', '2602']
# ['2015', 'Ximena', 'F', '2591']
# ['2015', 'Jade', 'F', '2549']
# ['2015', 'Liliana', 'F', '2545']
# ['2015', 'Brielle', 'F', '2519']
# ['2015', 'Ivy', 'F', '2489']
# ['2015', 'Trinity', 'F', '2485']
# ['2015', 'Josephine', 'F', '2477']
# ['2015', 'Adalyn', 'F', '2450']
# ['2015', 'Jocelyn', 'F', '2441']
# ['2015', 'Emery', 'F', '2409']
# ['2015', 'Adeline', 'F', '2391']
# ['2015', 'Jordyn', 'F', '2362']
# ['2015', 'Ariel', 'F', '2332']
# ...
# ['2015', 'Aayden', 'M', '179']
# ['2015', 'Gerard', 'M', '179']
# ['2015', 'Karim', 'M', '179']
# ['2015', 'Sidney', 'M', '179']
# ['2015', 'Aston', 'M', '178']
# ['2015', 'Greysen', 'M', '178']
# ['2015', 'Yael', 'M', '178']
# ['2015', 'Dale', 'M', '177']
# ['2015', 'Jaxx', 'M', '177']
# ['2015', 'Hollis', 'M', '176']
# ['2015', 'Isiah', 'M', '176']
# ['2015', 'Mac', 'M', '176']
# ['2015', 'Yaseen', 'M', '176']
# ['2015', 'Aidyn', 'M', '175']
# ['2015', 'Cormac', 'M', '175']
# ['2015', 'Kale', 'M', '175']
# ['2015', 'Eason', 'M', '174']
# ['2015', 'Dashiell', 'M', '173']
# ['2015', 'Eliot', 'M', '173']
# ['2015', 'Jaxxon', 'M', '173']
# ['2015', 'Jesiah', 'M', '173']
# ['2015', 'Nigel', 'M', '173']
# ['2015', 'Rylee', 'M', '173']
# ['2015', 'Shepherd', 'M', '173']
# ['2015', 'Edmund', 'M', '172']
# ['2015', 'Deegan', 'M', '171']
# ['2015', 'Gavyn', 'M', '171']
# ['2015', 'Reynaldo', 'M', '171']
# ['2015', 'Tyrell', 'M', '171']
# ['2015', 'Brendon', 'M', '170']
# ['2015', 'Colson', 'M', '170']
# ['2015', 'Corbyn', 'M', '170']
# ['2015', 'Izayah', 'M', '170']
# ['2015', 'Jaylin', 'M', '170']
# ['2015', 'Korbyn', 'M', '170']
# ['2015', 'Brenton', 'M', '169']
# ['2015', 'Giovanny', 'M', '169']
# ['2015', 'Joan', 'M', '169']
# ['2015', 'Menachem', 'M', '169']
# ['2015', 'Pierre', 'M', '169']
# ['2015', 'Shlomo', 'M', '169']
# ['2015', 'Jad', 'M', '168']
# ['2015', 'Jeremias', 'M', '168']
# ['2015', 'Johnathon', 'M', '168']
# ['2015', 'Sami', 'M', '168']
# ['2015', 'Damarion', 'M', '167']
# ['2015', 'Gonzalo', 'M', '167']
# ['2015', 'Kalvin', 'M', '167']
# ['2015', 'Mordechai', 'M', '167']
# ['2015', 'Vladimir', 'M', '167']
# ['2015', 'Aedan', 'M', '166']
# ['2015', 'Jarrett', 'M', '165']
# ['2015', 'Jaylon', 'M', '165']
# ['2015', 'Lian', 'M', '165']
# ['2015', 'Stephan', 'M', '165']
# ['2015', 'Carsen', 'M', '164']
# ['2015', 'Cristobal', 'M', '164']
# ['2015', 'Finnian', 'M', '164']
# ['2015', 'Glenn', 'M', '164']
# ['2015', 'Lathan', 'M', '164']
# ['2015', 'Lenny', 'M', '164']
# ['2015', 'Maxx', 'M', '164']
# ['2015', 'Corban', 'M', '163']
# ['2015', 'Deklan', 'M', '163']
# ['2015', 'Gus', 'M', '163']
# ['2015', 'Kabir', 'M', '163']
# ['2015', 'Kennedy', 'M', '163']
# ['2015', 'Mariano', 'M', '163']
# ['2015', 'Davon', 'M', '162']
# ['2015', 'Jovan', 'M', '162']
# ['2015', 'Koa', 'M', '161']
# ['2015', 'Linus', 'M', '161']
# ['2015', 'Lucien', 'M', '161']
# ['2015', 'Trystan', 'M', '161']
# ['2015', 'Daryl', 'M', '160']
# ['2015', 'Ronaldo', 'M', '160']
# ['2015', 'Yair', 'M', '160']
# ['2015', 'Hakeem', 'M', '159']
# ['2015', 'Syed', 'M', '159']
# ['2015', 'Tiago', 'M', '159']
# ['2015', 'Aditya', 'M', '158']
# ['2015', 'Broderick', 'M', '158']
# ['2015', 'Jayse', 'M', '158']
# ['2015', 'Shimon', 'M', '158']
# ['2015', 'Zev', 'M', '158']
# ['2015', 'Amar', 'M', '157']
# ['2015', 'Ansel', 'M', '157']
# ['2015', 'Dhruv', 'M', '157']
# ['2015', 'Ismail', 'M', '157']
# ['2015', 'Jakobe', 'M', '157']
# ['2015', 'Jordi', 'M', '157']
# ['2015', 'Keller', 'M', '157']
# ['2015', 'Ledger', 'M', '157']
# ['2015', 'Maksim', 'M', '157']
# ['2015', 'Ross', 'M', '157']
# ['2015', 'Karsyn', 'M', '156']
# ['2015', 'Kent', 'M', '156']
# ['2015', 'Slade', 'M', '156']
# ['2015', 'Thorin', 'M', '156']
# ['2015', 'Adolfo', 'M', '155']
# ['2015', 'Brogan', 'M', '155']
# ['2015', 'Marcello', 'M', '155']
# ['2015', 'Mikael', 'M', '155']
# ['2015', 'Donte', 'M', '154']
# ['2015', 'German', 'M', '154']
# ['2015', 'Jean', 'M', '154']
# ['2015', 'Jorden', 'M', '154']
# ['2015', 'Kaidyn', 'M', '154']
# ['2015', 'Kyren', 'M', '154']
# ['2015', 'Smith', 'M', '154']
# ['2015', 'Stone', 'M', '154']
# ['2015', 'Adler', 'M', '153']
# ['2015', 'Aries', 'M', '153']
# ['2015', 'Cian', 'M', '153']
# ['2015', 'Guy', 'M', '153']
# ['2015', 'Lyndon', 'M', '153']
# ['2015', 'Wallace', 'M', '153']
# ['2015', 'Zahir', 'M', '153']
# ['2015', 'Addison', 'M', '152']
# ['2015', 'Cornelius', 'M', '152']
# ['2015', 'Milton', 'M', '152']
# ['2015', 'Nick', 'M', '152']
# ['2015', 'Nikko', 'M', '152']
# ['2015', 'Raheem', 'M', '152']
# ['2015', 'Benedict', 'M', '151']
# ['2015', 'Bilal', 'M', '151']
# ['2015', 'Kyron', 'M', '151']
# ['2015', 'Neal', 'M', '151']
# ['2015', 'Carmine', 'M', '150']
# ['2015', 'Damion', 'M', '150']
# ['2015', 'Kyan', 'M', '150']
# ['2015', 'Viaan', 'M', '150']
# ['2015', 'Zack', 'M', '150']
# ['2015', 'Bernard', 'M', '149']
# ['2015', 'Darnell', 'M', '149']
# ['2015', 'Fredrick', 'M', '149']
# ['2015', 'Gian', 'M', '149']
# ['2015', 'Jionni', 'M', '149']
# ['2015', 'Elmer', 'M', '148']
# ['2015', 'Mikel', 'M', '148']
# ['2015', 'Murphy', 'M', '148']
# ['2015', 'Aubrey', 'M', '147']
# ['2015', 'Beck', 'M', '147']
# ['2015', 'Brighton', 'M', '147']
# ['2015', 'Ishmael', 'M', '147']
# ['2015', 'Jet', 'M', '147']
# ['2015', 'Zyon', 'M', '147']
# ['2015', 'Alton', 'M', '146']
# ['2015', 'Emir', 'M', '146']
# ['2015', 'Ever', 'M', '146']
# ['2015', 'Josias', 'M', '146']
# ['2015', 'Norman', 'M', '146']
# ['2015', 'Yitzchok', 'M', '146']
# ['2015', 'Archie', 'M', '145']
# ['2015', 'Armaan', 'M', '145']
# ['2015', 'Cael', 'M', '145']
# ['2015', 'Clifford', 'M', '145']
# ['2015', 'Humberto', 'M', '145']
# ['2015', 'Jai', 'M', '145']
# ['2015', 'Kallen', 'M', '145']
# ['2015', 'Marcellus', 'M', '145']
# ['2015', 'Masen', 'M', '145']
# ['2015', 'Aleksander', 'M', '144']
# ['2015', 'Kruz', 'M', '144']
# ['2015', 'Meir', 'M', '144']
# ['2015', 'Noble', 'M', '144']
# ['2015', 'Tayden', 'M', '144']
# ['2015', 'Viktor', 'M', '144']
# ['2015', 'Aamir', 'M', '143']
# ['2015', 'Aayan', 'M', '143']
# ['2015', 'Andreas', 'M', '143']
# ['2015', 'Bastian', 'M', '143']
# ['2015', 'Cal', 'M', '143']
# ['2015', 'Carlo', 'M', '143']
# ['2015', 'Salman', 'M', '143']
# ['2015', 'Destin', 'M', '142']
# ['2015', 'Eder', 'M', '142']
# ['2015', 'Elam', 'M', '142']
# ['2015', 'Mikhail', 'M', '142']
# ['2015', 'Wes', 'M', '142']
# ['2015', 'Amarion', 'M', '141']
# ['2015', 'Brennen', 'M', '141']
# ['2015', 'Carver', 'M', '141']
# ['2015', 'Colter', 'M', '141']
# ['2015', 'Gray', 'M', '141']
# ['2015', 'Monroe', 'M', '141']
# ['2015', 'Nikola', 'M', '141']
# ['2015', 'Vince', 'M', '141']
# ['2015', 'Bently', 'M', '140']
# ['2015', 'Cale', 'M', '140']
# ['2015', 'Diesel', 'M', '140']
# ['2015', 'Eamon', 'M', '140']
# ['2015', 'Kaiser', 'M', '140']
# ['2015', 'Barry', 'M', '139']
# ['2015', 'Dion', 'M', '139']
# ['2015', 'Perry', 'M', '139']
# ['2015', 'Quinten', 'M', '139']
# ['2015', 'Salem', 'M', '139']
# ['2015', 'Caius', 'M', '138']
# ['2015', 'Ewan', 'M', '138']
# ['2015', 'Haven', 'M', '138']
# ['2015', 'Idris', 'M', '138']
# ['2015', 'Ruger', 'M', '138']
# ['2015', 'Abdulrahman', 'M', '137']
# ['2015', 'Coy', 'M', '137']
# ['2015', 'Daylen', 'M', '137']
# ['2015', 'Graeme', 'M', '137']
# ['2015', 'Johann', 'M', '137']
# ['2015', 'Palmer', 'M', '137']
# ['2015', 'Sheldon', 'M', '137']
# ['2015', 'Tahj', 'M', '137']
# ['2015', 'Torin', 'M', '137']
# ['2015', 'Campbell', 'M', '136']
# ['2015', 'Lev', 'M', '136']
# ['2015', 'Lucius', 'M', '136']
# ['2015', 'Marquise', 'M', '136']
# ['2015', 'Ammar', 'M', '135']
# ['2015', 'Hussein', 'M', '135']
# ['2015', 'Johnpaul', 'M', '135']
# ['2015', 'Keon', 'M', '135']
# ['2015', 'Maddix', 'M', '135']
# ['2015', 'Tzvi', 'M', '135']
# ['2015', 'Bear', 'M', '134']
# ['2015', 'Gaige', 'M', '134']
# ['2015', 'Jakari', 'M', '134']
# ['2015', 'Pierson', 'M', '134']
# ['2015', 'Rishi', 'M', '134']
# ['2015', 'Zaylen', 'M', '134']
# ['2015', 'Alek', 'M', '133']
# ['2015', 'Atreyu', 'M', '133']
# ['2015', 'Aven', 'M', '133']
# ['2015', 'Avraham', 'M', '133']
# ['2015', 'Jacobi', 'M', '133']
# ['2015', 'Jarvis', 'M', '133']
# ['2015', 'Jenson', 'M', '133']
# ['2015', 'Link', 'M', '133']
# ['2015', 'Wiley', 'M', '133']
# ['2015', 'Ander', 'M', '132']
# ['2015', 'Baron', 'M', '132']
# ['2015', 'Benicio', 'M', '132']
# ['2015', 'Boaz', 'M', '132']
# ['2015', 'Forest', 'M', '132']
# ['2015', 'Jaceon', 'M', '132']
# ['2015', 'Jahmir', 'M', '132']
# ['2015', 'Keelan', 'M', '132']
# ['2015', 'Kilian', 'M', '132']
# ['2015', 'Leeland', 'M', '132']
# ['2015', 'Malakhi', 'M', '132']
# ['2015', 'Pranav', 'M', '132']
# ['2015', 'Rowdy', 'M', '132']
# ['2015', 'Yoel', 'M', '132']
# ['2015', 'Bernardo', 'M', '131']
# ['2015', 'Cashton', 'M', '131']
# ['2015', 'Francesco', 'M', '131']
# ['2015', 'Xavi', 'M', '131']
# ['2015', 'Siddharth', 'M', '130']
# ['2015', 'Adiel', 'M', '129']
# ['2015', 'Cordell', 'M', '129']
# ['2015', 'Dereck', 'M', '129']
# ['2015', 'Jayven', 'M', '129']
# ['2015', 'Kael', 'M', '129']
# ['2015', 'Ramsey', 'M', '129']
# ['2015', 'Avion', 'M', '128']
# ['2015', 'Earl', 'M', '128']
# ['2015', 'Eliyahu', 'M', '128']
# ['2015', 'Jael', 'M', '128']
# ['2015', 'Marshawn', 'M', '128']
# ['2015', 'Oren', 'M', '128']
# ['2015', 'Presley', 'M', '128']
# ['2015', 'Tevin', 'M', '128']
# ['2015', 'Zakaria', 'M', '128']
# ['2015', 'Aksel', 'M', '127']
# ['2015', 'Creed', 'M', '127']
# ['2015', 'Devonte', 'M', '127']
# ['2015', 'Eleazar', 'M', '127']
# ['2015', 'Jakai', 'M', '127']
# ['2015', 'Nova', 'M', '127']
# ['2015', 'Tobin', 'M', '127']
# ['2015', 'Dezmond', 'M', '126']
# ['2015', 'Elvin', 'M', '126']
# ['2015', 'Emil', 'M', '126']
# ['2015', 'Izaac', 'M', '126']
# ['2015', 'Jaxsen', 'M', '126']
# ['2015', 'Kanon', 'M', '126']
# ['2015', 'Laith', 'M', '126']
# ['2015', 'Massimo', 'M', '126']
# ['2015', 'Niam', 'M', '126']
# ['2015', 'Sebastien', 'M', '126']
# ['2015', 'Zephyr', 'M', '126']
# ['2015', 'Aaryan', 'M', '125']
# ['2015', 'Antony', 'M', '125']
# ['2015', 'Gionni', 'M', '125']
# ['2015', 'Hasan', 'M', '125']
# ['2015', 'Jaydan', 'M', '125']
# ['2015', 'Kaine', 'M', '125']
# ['2015', 'Kiyan', 'M', '125']
# ['2015', 'Sammy', 'M', '125']
# ['2015', 'Yandel', 'M', '125']
# ['2015', 'Axle', 'M', '124']
# ['2015', 'Coby', 'M', '124']
# ['2015', 'Demari', 'M', '124']
# ['2015', 'Hoyt', 'M', '124']
# ['2015', 'Kain', 'M', '124']
# ['2015', 'Kiran', 'M', '124']
# ['2015', 'Nestor', 'M', '124']
# ['2015', 'Tylan', 'M', '124']
# ['2015', 'Caysen', 'M', '123']
# ['2015', 'Deion', 'M', '123']
# ['2015', 'Jaeden', 'M', '123']
# ['2015', 'Jeremih', 'M', '123']
# ['2015', 'Nikhil', 'M', '123']
# ['2015', 'Rian', 'M', '123']
# ['2015', 'Westyn', 'M', '123']
# ['2015', 'Abdul', 'M', '122']
# ['2015', 'Azael', 'M', '122']
# ['2015', 'Bradyn', 'M', '122']
# ['2015', 'Demarion', 'M', '122']
# ['2015', 'Kenji', 'M', '122']
# ['2015', 'Ollie', 'M', '122']
# ['2015', 'Zackery', 'M', '122']
# ['2015', 'Zaden', 'M', '122']
# ['2015', 'Benaiah', 'M', '121']
# ['2015', 'Cillian', 'M', '121']
# ['2015', 'Devan', 'M', '121']
# ['2015', 'Eliel', 'M', '121']
# ['2015', 'Emmit', 'M', '121']
# ['2015', 'Hans', 'M', '121']
# ['2015', 'Isaak', 'M', '121']
# ['2015', 'Josh', 'M', '121']
# ['2015', 'Kurt', 'M', '121']
# ['2015', 'Watson', 'M', '121']
# ['2015', 'Bryer', 'M', '120']
# ['2015', 'Dovid', 'M', '120']
# ['2015', 'Kayleb', 'M', '120']
# ['2015', 'Mikah', 'M', '120']
# ['2015', 'Reign', 'M', '120']
# ['2015', 'Rico', 'M', '120']
# ['2015', 'Shamar', 'M', '120']
# ['2015', 'Austen', 'M', '119']
# ['2015', 'Jamel', 'M', '119']
# ['2015', 'Lamont', 'M', '119']
# ['2015', 'Lonnie', 'M', '119']
# ['2015', 'Rome', 'M', '119']
# ['2015', 'Ajay', 'M', '118']
# ['2015', 'Braxtyn', 'M', '118']
# ['2015', 'Chaz', 'M', '118']
# ['2015', 'Dillan', 'M', '118']
# ['2015', 'Donnie', 'M', '118']
# ['2015', 'Eddy', 'M', '118']
# ['2015', 'Kelton', 'M', '118']
# ['2015', 'Onyx', 'M', '118']
# ['2015', 'Thor', 'M', '118']
# ['2015', 'Abdirahman', 'M', '117']
# ['2015', 'Faris', 'M', '117']
# ['2015', 'Kolt', 'M', '117']
# ['2015', 'Leyton', 'M', '117']
# ['2015', 'Pharaoh', 'M', '117']
# ['2015', 'Umar', 'M', '117']
# ['2015', 'Zephaniah', 'M', '117']
# ['2015', 'Benny', 'M', '116']
# ['2015', 'Clint', 'M', '116']
# ['2015', 'Hagen', 'M', '116']
# ['2015', 'Lazarus', 'M', '116']
# ['2015', 'Noam', 'M', '116']
# ['2015', 'Syncere', 'M', '116']
# ['2015', 'Yasir', 'M', '116']
# ['2015', 'Zakariya', 'M', '116']
# ['2015', 'Zeus', 'M', '116']
# ['2015', 'Hiram', 'M', '115']
# ['2015', 'Jacen', 'M', '115']
# ['2015', 'Jessiah', 'M', '115']
# ['2015', 'Shepard', 'M', '115']
# ['2015', 'Yeshua', 'M', '115']
# ['2015', 'Akeem', 'M', '114']
# ['2015', 'Brandt', 'M', '114']
# ['2015', 'Canyon', 'M', '114']
# ['2015', 'Cecil', 'M', '114']
# ['2015', 'Dakari', 'M', '114']
# ['2015', 'Don', 'M', '114']
# ['2015', 'Ishan', 'M', '114']
# ['2015', 'Loki', 'M', '114']
# ['2015', 'Ramses', 'M', '114']
# ['2015', 'Arham', 'M', '113']
# ['2015', 'Duane', 'M', '113']
# ['2015', 'Kadyn', 'M', '113']
# ['2015', 'Tyrese', 'M', '113']
# ['2015', 'Antwan', 'M', '112']
# ['2015', 'Dashawn', 'M', '112']
# ['2015', 'Geovanni', 'M', '112']
# ['2015', 'Giuseppe', 'M', '112']
# ['2015', 'Jethro', 'M', '112']
# ['2015', 'Krew', 'M', '112']
# ['2015', 'Savion', 'M', '112']
# ['2015', 'Tegan', 'M', '112']
# ['2015', 'Truett', 'M', '112']
# ['2015', 'Zavion', 'M', '112']
# ['2015', 'Alexandre', 'M', '111']
# ['2015', 'Ansh', 'M', '111']
# ['2015', 'Courtney', 'M', '111']
# ['2015', 'Elan', 'M', '111']
# ['2015', 'Everest', 'M', '111']
# ['2015', 'Irvin', 'M', '111']
# ['2015', 'Javen', 'M', '111']
# ['2015', 'Khai', 'M', '111']
# ['2015', 'Marek', 'M', '111']
# ['2015', 'Veer', 'M', '111']
# ['2015', 'Amauri', 'M', '110']
# ['2015', 'Bronx', 'M', '110']
# ['2015', 'Clifton', 'M', '110']
# ['2015', 'Denis', 'M', '110']
# ['2015', 'Grayden', 'M', '110']
# ['2015', 'Isa', 'M', '110']
# ['2015', 'Jamil', 'M', '110']
# ['2015', 'Judd', 'M', '110']
# ['2015', 'Keyon', 'M', '110']
# ['2015', 'Korben', 'M', '110']
# ['2015', 'Rishaan', 'M', '110']
# ['2015', 'Yousif', 'M', '110']
# ['2015', 'Bailey', 'M', '109']
# ['2015', 'Cedar', 'M', '109']
# ['2015', 'Ely', 'M', '109']
# ['2015', 'Jahlil', 'M', '109']
# ['2015', 'Koby', 'M', '109']
# ['2015', 'Markel', 'M', '109']
# ['2015', 'Oskar', 'M', '109']
# ['2015', 'Rigoberto', 'M', '109']
# ['2015', 'Tiberius', 'M', '109']
# ['2015', 'Wolfgang', 'M', '109']
# ['2015', 'Chayce', 'M', '108']
# ['2015', 'Deven', 'M', '108']
# ['2015', 'Levon', 'M', '108']
# ['2015', 'Lloyd', 'M', '108']
# ['2015', 'Carsyn', 'M', '107']
# ['2015', 'Devyn', 'M', '107']
# ['2015', 'Dov', 'M', '107']
# ['2015', 'Drayden', 'M', '107']
# ['2015', 'Floyd', 'M', '107']
# ['2015', 'Fynn', 'M', '107']
# ['2015', 'Jaron', 'M', '107']
# ['2015', 'Kaius', 'M', '107']
# ['2015', 'Kyran', 'M', '107']
# ['2015', 'Laken', 'M', '107']
# ['2015', 'Monte', 'M', '107']
# ['2015', 'Stephon', 'M', '107']
# ['2015', 'Britton', 'M', '106']
# ['2015', 'Estevan', 'M', '106']
# ['2015', 'Johnnie', 'M', '106']
# ['2015', 'Jones', 'M', '106']
# ['2015', 'Khari', 'M', '106']
# ['2015', 'Kyrin', 'M', '106']
# ['2015', 'Marcelino', 'M', '106']
# ['2015', 'Matheo', 'M', '106']
# ['2015', 'Olin', 'M', '106']
# ['2015', 'Arman', 'M', '105']
# ['2015', 'Banks', 'M', '105']
# ['2015', 'Damoni', 'M', '105']
# ['2015', 'Dev', 'M', '105']
# ['2015', 'Nazir', 'M', '105']
# ['2015', 'Yakov', 'M', '105']
# ['2015', 'Domenic', 'M', '104']
# ['2015', 'Fischer', 'M', '104']
# ['2015', 'Henley', 'M', '104']
# ['2015', 'Maxon', 'M', '104']
# ['2015', 'Morris', 'M', '104']
# ['2015', 'Raylen', 'M', '104']
# ['2015', 'Saif', 'M', '104']
# ['2015', 'Stryker', 'M', '104']
# ['2015', 'Yariel', 'M', '104']
# ['2015', 'Zaine', 'M', '104']
# ['2015', 'Arnav', 'M', '103']
# ['2015', 'Austyn', 'M', '103']
# ['2015', 'Azriel', 'M', '103']
# ['2015', 'Braxten', 'M', '103']
# ['2015', 'Caspian', 'M', '103']
# ['2015', 'Damir', 'M', '103']
# ['2015', 'Dwight', 'M', '103']
# ['2015', 'Jasiel', 'M', '103']
# ['2015', 'Javian', 'M', '103']
# ['2015', 'Maddex', 'M', '103']
# ['2015', 'Rio', 'M', '103']
# ['2015', 'Yasin', 'M', '103']
# ['2015', 'Dewayne', 'M', '102']
# ['2015', 'Kylar', 'M', '102']
# ['2015', 'Mattias', 'M', '102']
# ['2015', 'Mickey', 'M', '102']
# ['2015', 'Montgomery', 'M', '102']
# ['2015', 'Ransom', 'M', '102']
# ['2015', 'Shaurya', 'M', '102']
# ['2015', 'Trevon', 'M', '102']
# ['2015', 'Vernon', 'M', '102']
# ['2015', 'Wilmer', 'M', '102']
# ['2015', 'Zakai', 'M', '102']
# ['2015', 'Gareth', 'M', '101']
# ['2015', 'Henri', 'M', '101']
# ['2015', 'Ilan', 'M', '101']
# ['2015', 'Kace', 'M', '101']
# ['2015', 'Kasey', 'M', '101']
# ['2015', 'Kelly', 'M', '101']
# ['2015', 'Klayton', 'M', '101']
# ['2015', 'Maximillian', 'M', '101']
# ['2015', 'Myron', 'M', '101']
# ['2015', 'Terence', 'M', '101']
# ['2015', 'Zaidyn', 'M', '101']
# ['2015', 'Alexavier', 'M', '100']
# ['2015', 'Ambrose', 'M', '100']
# ['2015', 'Amias', 'M', '100']
# ['2015', 'Anas', 'M', '100']
# ['2015', 'Aryeh', 'M', '100']
# ['2015', 'Brigham', 'M', '100']
# ['2015', 'Fred', 'M', '100']
# ['2015', 'Irving', 'M', '100']
# ['2015', 'Jakobi', 'M', '100']
# ['2015', 'Jaquan', 'M', '100']
# ['2015', 'Kyng', 'M', '100']
# ['2015', 'Kyzer', 'M', '100']
# ['2015', 'Lester', 'M', '100']
# ['2015', 'Marko', 'M', '100']
# ['2015', 'Mauro', 'M', '100']
# ['2015', 'Niklaus', 'M', '100']
# ['2015', 'Osiris', 'M', '100']
# ['2015', 'Steele', 'M', '100']

# %%
# Construyamos una lista con todos los nombres

listaNombres = []

with open('babyNamesUSYOB-mostpopular.csv', "r") as file:
  lecturaCSV = csv.reader(file)
  for fila in lecturaCSV:
    listaNombres.append(fila[1])

# %%
#
listaNombres = listaNombres[1:]
listaNombres
# Out:
# ['Mary',
#  'Anna',
#  'Emma',
#  'Elizabeth',
#  'Minnie',
#  'Margaret',
#  'Ida',
#  'Alice',
#  'Bertha',
#  'Sarah',
#  'Annie',
#  'Clara',
#  'Ella',
#  'Florence',
#  'Cora',
#  'Martha',
#  'Laura',
#  'Nellie',
#  'Grace',
#  'Carrie',
#  'Maude',
#  'Mabel',
#  'Bessie',
#  'Jennie',
#  'Gertrude',
#  'Julia',
#  'Hattie',
#  'Edith',
#  'Mattie',
#  'Rose',
#  'Catherine',
#  'Lillian',
#  'Ada',
#  'Lillie',
#  'Helen',
#  'Jessie',
#  'Louise',
#  'Ethel',
#  'Lula',
#  'Myrtle',
#  'Eva',
#  'Frances',
#  'Lena',
#  'Lucy',
#  'Edna',
#  'Maggie',
#  'Pearl',
#  'Daisy',
#  'Fannie',
#  'Josephine',
#  'Dora',
#  'Rosa',
#  'Katherine',
#  'Agnes',
#  'Marie',
#  'Nora',
#  'May',
#  'Mamie',
#  'Blanche',
#  'Stella',
#  'Ellen',
#  'Nancy',
#  'Effie',
#  'Sallie',
#  'Nettie',
#  'Della',
#  'Lizzie',
#  'Flora',
#  'Susie',
#  'Maud',
#  'Mae',
#  'Etta',
#  'Harriet',
#  'Sadie',
#  'Caroline',
#  'Katie',
#  'Lydia',
#  'Elsie',
#  'Kate',
#  'Susan',
#  'Mollie',
#  'Alma',
#  'Addie',
#  'Georgia',
#  'Eliza',
#  'Lulu',
#  'Nannie',
#  'Lottie',
#  'Amanda',
#  'Belle',
#  'Charlotte',
#  'Rebecca',
#  'Ruth',
#  'Viola',
#  'Olive',
#  'Amelia',
#  'Hannah',
#  'Jane',
#  'Virginia',
#  'Emily',
#  'Matilda',
#  'Irene',
#  'Kathryn',
#  'Esther',
#  'Willie',
#  'Henrietta',
#  'Ollie',
#  'Amy',
#  'Rachel',
#  'Sara',
#  'Estella',
#  'Theresa',
#  'Augusta',
#  'Ora',
#  'Pauline',
#  'Josie',
#  'Lola',
#  'Sophia',
#  'Leona',
#  'Anne',
#  'Mildred',
#  'Ann',
#  'Beulah',
#  'Callie',
#  'Lou',
#  'Delia',
#  'Eleanor',
#  'Barbara',
#  'Iva',
#  'Louisa',
#  'Maria',
#  'Mayme',
#  'Evelyn',
#  'Estelle',
#  'Nina',
#  'Betty',
#  'Marion',
#  'Bettie',
#  'Dorothy',
#  'Luella',
#  'Inez',
#  'Lela',
#  'Rosie',
#  'Allie',
#  'Millie',
#  'John',
#  'William',
#  'James',
#  'Charles',
#  'George',
#  'Frank',
#  'Joseph',
#  'Thomas',
#  'Henry',
#  'Robert',
#  'Edward',
#  'Harry',
#  'Walter',
#  'Arthur',
#  'Fred',
#  'Albert',
#  'Samuel',
#  'David',
#  'Louis',
#  'Joe',
#  'Charlie',
#  'Clarence',
#  'Richard',
#  'Andrew',
#  'Daniel',
#  'Ernest',
#  'Will',
#  'Jesse',
#  'Oscar',
#  'Lewis',
#  'Peter',
#  'Benjamin',
#  'Frederick',
#  'Willie',
#  'Alfred',
#  'Sam',
#  'Roy',
#  'Herbert',
#  'Jacob',
#  'Tom',
#  'Elmer',
#  'Carl',
#  'Lee',
#  'Howard',
#  'Martin',
#  'Michael',
#  'Bert',
#  'Herman',
#  'Jim',
#  'Francis',
#  'Harvey',
#  'Earl',
#  'Eugene',
#  'Ralph',
#  'Ed',
#  'Claude',
#  'Edwin',
#  'Ben',
#  'Charley',
#  'Paul',
#  'Edgar',
#  'Isaac',
#  'Otto',
#  'Luther',
#  'Lawrence',
#  'Ira',
#  'Patrick',
#  'Guy',
#  'Oliver',
#  'Theodore',
#  'Hugh',
#  'Clyde',
#  'Alexander',
#  'August',
#  'Floyd',
#  'Homer',
#  'Jack',
#  'Leonard',
#  'Horace',
#  'Marion',
#  'Philip',
#  'Allen',
#  'Archie',
#  'Stephen',
#  'Chester',
#  'Willis',
#  'Raymond',
#  'Rufus',
#  'Warren',
#  'Jessie',
#  'Milton',
#  'Alex',
#  'Leo',
#  'Julius',
#  'Ray',
#  'Sidney',
#  'Bernard',
#  'Dan',
#  'Jerry',
#  'Calvin',
#  'Perry',
#  'Dave',
#  'Anthony',
#  'Eddie',
#  'Amos',
#  'Dennis',
#  'Clifford',
#  'Leroy',
#  'Wesley',
#  'Alonzo',
#  'Garfield',
#  'Franklin',
#  'Emil',
#  'Leon',
#  'Nathan',
#  'Harold',
#  'Matthew',
#  'Levi',
#  'Moses',
#  'Everett',
#  'Lester',
#  'Winfield',
#  'Adam',
#  'Lloyd',
#  'Mack',
#  'Fredrick',
#  'Jay',
#  'Jess',
#  'Melvin',
#  'Noah',
#  'Aaron',
#  'Alvin',
#  'Norman',
#  'Gilbert',
#  'Elijah',
#  'Victor',
#  'Mary',
#  'Anna',
#  'Emma',
#  'Elizabeth',
#  'Margaret',
#  'Minnie',
#  'Ida',
#  'Annie',
#  'Bertha',
#  'Alice',
#  'Clara',
#  'Sarah',
#  'Ella',
#  'Nellie',
#  'Grace',
#  'Florence',
#  'Martha',
#  'Cora',
#  'Laura',
#  'Carrie',
#  'Maude',
#  'Bessie',
#  'Mabel',
#  'Gertrude',
#  'Ethel',
#  'Jennie',
#  'Edith',
#  'Hattie',
#  'Mattie',
#  'Julia',
#  'Rose',
#  'Lillian',
#  'Lillie',
#  'Eva',
#  'Jessie',
#  'Lula',
#  'Myrtle',
#  'Pearl',
#  'Edna',
#  'Catherine',
#  'Ada',
#  'Louise',
#  'Helen',
#  'Lucy',
#  'Frances',
#  'Dora',
#  'Fannie',
#  'Josephine',
#  'Daisy',
#  'Lena',
#  'Maggie',
#  'Katherine',
#  'Rosa',
#  'Marie',
#  'Nora',
#  'Effie',
#  'Blanche',
#  'May',
#  'Nancy',
#  'Della',
#  'Agnes',
#  'Nettie',
#  'Sallie',
#  'Stella',
#  'Ellen',
#  'Mamie',
#  'Lizzie',
#  'Susie',
#  'Sadie',
#  'Elsie',
#  'Maud',
#  'Flora',
#  'Caroline',
#  'Etta',
#  'Mae',
#  'Lulu',
#  'Lydia',
#  'Alma',
#  'Susan',
#  'Lottie',
#  'Addie',
#  'Mollie',
#  'Katie',
#  'Ruth',
#  'Harriet',
#  'Kate',
#  'Amanda',
#  'Nannie',
#  'Georgia',
#  'Emily',
#  'Eliza',
#  'Viola',
#  'Amelia',
#  'Willie',
#  'Charlotte',
#  'Rebecca',
#  'Belle',
#  'Kathryn',
#  'Jane',
#  'Olive',
#  'Virginia',
#  'Irene',
#  'Hannah',
#  'Ora',
#  'Esther',
#  'Matilda',
#  'Henrietta',
#  'Theresa',
#  'Ollie',
#  'Pauline',
#  'Estella',
#  'Beulah',
#  'Augusta',
#  'Rachel',
#  'Mildred',
#  'Josie',
#  'Sara',
#  'Amy',
#  'Louisa',
#  'Luella',
#  'Leona',
#  'Anne',
#  'Ann',
#  'Barbara',
#  'Lola',
#  'Estelle',
#  'Lela',
#  'Millie',
#  'Nina',
#  'Iva',
#  'Sophia',
#  'Maria',
#  'Ruby',
#  'Victoria',
#  'Evelyn',
#  'Mayme',
#  'Alta',
#  'Lou',
#  'Janie',
#  'Betty',
#  'Delia',
#  'Eleanor',
#  'Marion',
#  'Dorothy',
#  'Ina',
#  'Celia',
#  'Callie',
#  'Bettie',
#  'John',
#  'William',
#  'James',
#  'George',
#  'Charles',
#  'Frank',
#  'Joseph',
#  'Henry',
#  'Thomas',
#  'Edward',
#  'Robert',
#  'Harry',
#  'Walter',
#  'Arthur',
#  'Fred',
#  'Albert',
#  'Samuel',
#  'David',
#  'Louis',
#  'Charlie',
#  'Clarence',
#  'Richard',
#  'Joe',
#  'Andrew',
#  'Ernest',
#  'Will',
#  'Jesse',
#  'Oscar',
#  'Daniel',
#  'Willie',
#  'Benjamin',
#  'Sam',
#  'Alfred',
#  'Roy',
#  'Lewis',
#  'Frederick',
#  'Peter',
#  'Elmer',
#  'Jacob',
#  'Herbert',
#  'Carl',
#  'Howard',
#  'Tom',
#  'Lee',
#  'Ralph',
#  'Martin',
#  'Jim',
#  'Earl',
#  'Eugene',
#  'Bert',
#  'Edgar',
#  'Herman',
#  'Claude',
#  'Michael',
#  'Paul',
#  'Ben',
#  'Ira',
#  'Harvey',
#  'Chester',
#  'Edwin',
#  'Ed',
#  'Charley',
#  'Francis',
#  'Isaac',
#  'Luther',
#  'Lawrence',
#  'Oliver',
#  'Clyde',
#  'Otto',
#  'Hugh',
#  'Alexander',
#  'Leonard',
#  'Jack',
#  'Raymond',
#  'Patrick',
#  'Guy',
#  'Homer',
#  'Floyd',
#  'Theodore',
#  'Allen',
#  'August',
#  'Marion',
#  'Philip',
#  'Warren',
#  'Horace',
#  'Dan',
#  'Ray',
#  'Garfield',
#  'Stephen',
#  'Emil',
#  'Jessie',
#  'Milton',
#  'Willis',
#  'Calvin',
#  'Dave',
#  'Bernard',
#  'Julius',
#  'Leroy',
#  'Sidney',
#  'Anthony',
#  'Archie',
#  'Perry',
#  'Leo',
#  'Leon',
#  'Rufus',
#  'Harold',
#  'Franklin',
#  'Adam',
#  'Alex',
#  'Alonzo',
#  'Everett',
#  'Clifford',
#  'Victor',
#  'Eddie',
#  'Alvin',
#  'Levi',
#  'Amos',
#  'Roscoe',
#  'Wesley',
#  'Mary',
#  'Anna',
#  'Emma',
#  'Elizabeth',
#  'Minnie',
#  'Margaret',
#  'Ida',
#  'Alice',
#  'Bertha',
#  'Annie',
#  'Clara',
#  'Sarah',
#  'Florence',
#  'Martha',
#  'Ella',
#  'Grace',
#  'Laura',
#  'Bessie',
#  'Nellie',
#  'Maude',
#  'Cora',
#  'Carrie',
#  'Mabel',
#  'Ethel',
#  'Mattie',
#  'Gertrude',
#  'Jennie',
#  'Rose',
#  'Edith',
#  'Hattie',
#  'Helen',
#  'Lillian',
#  'Pearl',
#  'Louise',
#  'Julia',
#  'Lillie',
#  'Jessie',
#  'Myrtle',
#  'Edna',
#  'Lula',
#  'Eva',
#  'Catherine',
#  'Lena',
#  'Ada',
#  'Frances',
#  'Lucy',
#  'Fannie',
#  'Daisy',
#  'Josephine',
#  'Maggie',
#  'Dora',
#  'Katherine',
#  'Marie',
#  'Agnes',
#  'Effie',
#  'Blanche',
#  'Rosa',
#  'Nora',
#  'May',
#  'Mamie',
#  'Stella',
#  'Lizzie',
#  'Sallie',
#  'Ellen',
#  'Elsie',
#  'Della',
#  'Nancy',
#  'Nettie',
#  'Maud',
#  'Susie',
#  'Mae',
#  'Sadie',
#  'Flora',
#  'Alma',
#  'Etta',
#  'Lydia',
#  'Addie',
#  'Katie',
#  'Susan',
#  'Ruth',
#  'Georgia',
#  'Lottie',
#  'Viola',
#  'Mollie',
#  'Caroline',
#  'Nannie',
#  'Kate',
#  'Olive',
#  'Willie',
#  'Harriet',
#  'Amanda',
#  'Eliza',
#  'Lulu',
#  'Virginia',
#  'Emily',
#  'Kathryn',
#  'Esther',
#  'Belle',
#  'Rebecca',
#  'Charlotte',
#  'Jane',
#  'Amelia',
#  'Matilda',
#  'Irene',
#  'Ollie',
#  'Hannah',
#  'Henrietta',
#  'Pauline',
#  'Rachel',
#  'Estella',
#  'Amy',
#  'Beulah',
#  'Augusta',
#  'Ora',
#  'Sara',
#  'Sophia',
#  'Eleanor',
#  'Lola',
#  'Mildred',
#  'Nina',
#  'Theresa',
#  'Josie',
#  'Anne',
#  'Leona',
#  'Ann',
#  'Delia',
#  'Lela',
#  'Marion',
#  'Mayme',
#  'Rosie',
#  'Bettie',
#  'Ruby',
#  'Iva',
#  'Janie',
#  'Estelle',
#  'Victoria',
#  'Lou',
#  'Barbara',
#  'Callie',
#  'Louisa',
#  'Celia',
#  'Evelyn',
#  'Mable',
#  'Beatrice',
#  'Betty',
#  'Millie',
#  'Maria',
#  'Alta',
#  'Luella',
#  'Dorothy',
#  'Allie',
#  'Birdie',
#  'Essie',
#  'Ola',
#  'Sophie',
#  'Inez',
#  'Ina',
#  'Tillie',
#  'Nell',
#  'Rena',
#  'John',
#  'William',
#  'James',
#  'George',
#  'Charles',
#  'Frank',
#  'Joseph',
#  'Thomas',
#  'Henry',
#  'Robert',
#  'Edward',
#  'Harry',
#  'Walter',
#  'Arthur',
#  'Fred',
#  'Albert',
#  'Samuel',
#  'Louis',
#  'David',
#  'Clarence',
#  'Charlie',
#  'Richard',
#  'Joe',
#  'Andrew',
#  'Will',
#  'Jesse',
#  'Ernest',
#  'Oscar',
#  'Daniel',
#  'Sam',
#  'Willie',
#  'Alfred',
#  'Roy',
#  'Benjamin',
#  'Carl',
#  'Peter',
#  'Frederick',
#  'Elmer',
#  'Lewis',
#  'Herbert',
#  'Lee',
#  'Howard',
#  'Ralph',
#  'Paul',
#  'Jim',
#  'Jacob',
#  'Tom',
#  'Martin',
#  'Earl',
#  'Claude',
#  'Herman',
#  'Bert',
#  'Eugene',
#  'Ed',
#  'Ben',
#  'Francis',
#  'Michael',
#  'Edgar',
#  'Edwin',
#  'Chester',
#  'Harvey',
#  'Clyde',
#  'Lawrence',
#  'Luther',
#  'Isaac',
#  'Jack',
#  'Charley',
#  'Guy',
#  'Otto',
#  'Patrick',
#  'Ira',
#  'Oliver',
#  'Hugh',
#  'August',
#  'Theodore',
#  'Floyd',
#  'Leonard',
#  'Raymond',
#  'Alexander',
#  'Allen',
#  'Stephen',
#  'Archie',
#  'Ray',
#  'Jessie',
#  'Homer',
#  'Warren',
#  'Philip',
#  'Horace',
#  'Alex',
#  'Eddie',
#  'Julius',
#  'Emil',
#  'Marion',
#  'Clifford',
#  'Milton',
#  'Leroy',
#  'Dan',
#  'Rufus',
#  'Leo',
#  'Sidney',
#  'Mack',
#  'Wesley',
#  'Bernard',
#  'Willis',
#  'Anthony',
#  'Dave',
#  'Everett',
#  'Dennis',
#  'Amos',
#  'Lester',
#  'Alonzo',
#  'Perry',
#  'Alvin',
#  'Leon',
#  'Harold',
#  'Percy',
#  'Calvin',
#  'Jess',
#  'Leslie',
#  'Lloyd',
#  'Gus',
#  'Otis',
#  'Adam',
#  'Nathan',
#  'Franklin',
#  'Elijah',
#  'Matthew',
#  'Victor',
#  'Noah',
#  'Cornelius',
#  'Norman',
#  'Jerry',
#  'Levi',
#  'Earnest',
#  'Hiram',
#  'Nelson',
#  'Phillip',
#  'Wallace',
#  'Maurice',
#  'Mary',
#  'Anna',
#  'Emma',
#  'Elizabeth',
#  'Minnie',
#  'Margaret',
#  'Bertha',
#  'Ida',
#  'Annie',
#  'Clara',
#  'Alice',
#  'Sarah',
#  'Grace',
#  'Florence',
#  'Martha',
#  'Ella',
#  'Nellie',
#  'Bessie',
#  'Laura',
#  'Ethel',
#  'Carrie',
#  'Maude',
#  'Mabel',
#  'Cora',
#  'Gertrude',
#  'Lillian',
#  'Jennie',
#  'Hattie',
#  'Pearl',
#  'Mattie',
#  'Edith',
#  'Eva',
#  'Rose',
#  'Julia',
#  'Helen',
#  'Catherine',
#  'Myrtle',
#  'Louise',
#  'Lillie',
#  'Jessie',
#  'Edna',
#  'Lena',
#  'Lula',
#  'Ada',
#  'Frances',
#  'Josephine',
#  'Fannie',
#  'Lucy',
#  'Maggie',
#  'Daisy',
#  'Dora',
#  'Agnes',
#  'Marie',
#  'Blanche',
#  'Nora',
#  'Katherine',
#  'May',
#  'Mamie',
#  'Stella',
#  'Effie',
#  'Rosa',
#  'Ellen',
#  'Lizzie',
#  'Nettie',
#  'Elsie',
#  'Della',
#  'Susie',
#  'Maud',
#  'Sadie',
#  'Mae',
#  'Nancy',
#  'Sallie',
#  'Flora',
#  'Ruth',
#  'Lydia',
#  'Lottie',
#  'Addie',
#  'Katie',
#  'Alma',
#  'Etta',
#  'Emily',
#  'Harriet',
#  'Viola',
#  'Georgia',
#  'Susan',
#  'Caroline',
#  'Nannie',
#  'Lulu',
#  'Mollie',
#  'Kate',
#  'Olive',
#  'Charlotte',
#  'Kathryn',
#  'Amanda',
#  'Eliza',
#  'Willie',
#  'Amelia',
#  'Belle',
#  'Esther',
#  'Irene',
#  'Ollie',
#  'Jane',
#  'Rebecca',
#  'Theresa',
#  'Virginia',
#  'Estella',
#  'Beulah',
#  'Augusta',
#  'Ora',
#  'Amy',
#  'Hannah',
#  'Henrietta',
#  'Pauline',
#  'Eleanor',
#  'Marion',
#  'Anne',
#  'Mildred',
#  'Sara',
#  'Leona',
#  'Nina',
#  'Rachel',
#  'Lola',
#  'Iva',
#  'Ann',
#  'Matilda',
#  'Lela',
#  'Ruby',
#  'Delia',
#  'Sophia',
#  'Mayme',
#  'Millie',
#  'Estelle',
#  'Josie',
#  'Allie',
#  'Louisa',
#  'Lou',
#  'Dorothy',
#  'Inez',
#  'Maria',
#  'Essie',
#  'Evelyn',
#  'Barbara',
#  'Callie',
#  'Janie',
#  'Bettie',
#  'Beatrice',
#  'Ola',
#  'Winifred',
#  'Hazel',
#  'Betty',
#  'Luella',
#  'Mable',
#  'Cornelia',
#  ...]

# %%
# Mostremos los primeros 10 elementos de listaNombres
listaNombres[:9+1]
# Out:
# ['Mary',
#  'Anna',
#  'Emma',
#  'Elizabeth',
#  'Minnie',
#  'Margaret',
#  'Ida',
#  'Alice',
#  'Bertha',
#  'Sarah']

# %%
# Implementemos una funcion que reciba dos argumentos
# Primer argumento : lista de nombres
# Segundo argumento : un caracter / letra
# La funcion va devolver el numero de nombres que inician con esa letra

def CuentaNombres(lista , letra):
  """
  Funcion que calcule el numero de nombres que inician con el
  caracter letra en la variables lista

    lista : list
    letra : str (de un unico elemento)
  """

  NumLetra = 0
  for nombre in lista:
    if nombre[0] == letra:
      NumLetra = NumLetra + 1
  return NumLetra

# %%
help(CuentaNombres)
# Out:
# Help on function CuentaNombres in module __main__:
#
# CuentaNombres(lista, letra)
#     Funcion que calcule el numero de nombres que inician con el
#     caracter letra en la variables lista
#
#       lista : list
#       letra : str (de un unico elemento)

# %%
# Contemos los nombres que inician con la "A"
CuentaNombres(listaNombres, "A")
# Out:
# 20467

# %%
# Contemos los nombres que inician con la letra "W"
CuentaNombres(listaNombres, "W")
# Out:
# 3776

# %%
# Calcular cuantos nombres existen en ListaNombres para cada letra del abecedario
import string

# Empaquetemos el resultado en un diccionario
dataNombres = {}.fromkeys(string.ascii_uppercase)

for letra in string.ascii_uppercase:
  dataNombres[letra] = CuentaNombres(listaNombres, letra)

dataNombres
# Out:
# {'A': 20467,
#  'B': 10902,
#  'C': 17480,
#  'D': 14524,
#  'E': 12459,
#  'F': 4637,
#  'G': 7724,
#  'H': 5822,
#  'I': 3748,
#  'J': 19437,
#  'K': 12731,
#  'L': 15367,
#  'M': 19146,
#  'N': 5605,
#  'O': 2444,
#  'P': 4591,
#  'Q': 445,
#  'R': 13182,
#  'S': 13829,
#  'T': 9335,
#  'U': 356,
#  'V': 3664,
#  'W': 3776,
#  'X': 197,
#  'Y': 1158,
#  'Z': 1235}

# %%
CuentaNombres("A", listaNombres)

# Observamos que CuentaNombres tiene en consideracion el orden en los argumentos
# CuentaNombres es una funcion de Argumentos por posicion
# Out:
# 0

# %%
CuentaNombres(listaNombres[666:6667], "A")
# Out:
# 512

# %%
# LLamemos a la funcion utilizando los argumentos por nombres
CuentaNombres(lista = listaNombres[100:10001], letra = "P")
# Out:
# 216

# %%
# Cuanto especificamos los nombres de los argumentos podemos intervcambiar
# el orden
CuentaNombres(letra = "Z", lista = listaNombres)
# Out:
# 1235

# %%
# Funciones con argumentos con valores por defecto

# Implementemos el calculo de la fza electrica entre dos cargas puntuales
# (q1 y q2) separadas una distancia d (metros). Usando la ley de Coulomb

def coulomb(q1,q2,d,k = 9*10**9):
  return k*q1*q2/d**2

# %%
# Usemos la funcion coulomb considerando argumentos por posicion
F1 = coulomb(5.6*10**(-12), 3.9*10**(-11), 2.8*10**(-2))
F1
# Out:
# 2.507142857142857e-09

# %%
# Usemos la funcion de coulomb usando argumentos por posicion, pero
# modificando el valor de la constante k
F2 = coulomb(5.6*10**(-12), 3.9*10**(-11), 2.8*10**(-2), 9.81*10**9)
F2
# Out:
# 2.7327857142857143e-09

# %%
# Usemos argumentos por nombre sin modificar el valor de k
F4 = coulomb(d = 2.8*10**(-2), q2= 3.9*10**(-11), q1 = 5.6*10**(-12))
F4
# Out:
# 2.507142857142857e-09

# %%
# Funciones con argumentos de longitud variable

# Consideremos implementar una funcion que sume dos numeros
def adicion(x1,x2):
  return x1+x2

# %%
# Ejemplito de ejecucion de la funcion adicion usando argumentos por posicion
adicion(12,9.6)
# Out:
# 21.6

# %%
# Ejemplito de ejecucion de la funcion adicion usando argumentos por nombre
adicion(x2 = 9.6, x1 = 12)
# Out:
# 21.6

# %%
adicion(1,2,12.3,9)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-afea700d3861> in <cell line: 1>()
# ----> 1 adicion(1,2,12.3,9)
#
# TypeError: adicion() takes 2 positional arguments but 4 were given

# %%
# En vista delo problema obtenido en la celda anterior : No sabemos cuantos numeros
# son los que vamor a sumar

# Una primera forma es considerar la implementacion de una funcion con un numero
# de argumentos variable. Empaquetando los input de la funcion en una lista

def adicion2(listaNumeros):
  """
  funcion que calcule la suma de todos los elementos de una lista de numeros
  """

  sumaTotal = 0
  for elemento in listaNumeros:
    sumaTotal = sumaTotal +elemento
  return sumaTotal

# %%
# Ejemplito
adicion2([12,13,14])
# Out:
# 39

# %%
# Otro ejemplito
adicion2([12,23,345,45,56,456,45,64,56,456,45,64,5,6])
# Out:
# 1678

# %%
# Limitante que tiene adicion2 : Solo recibe un unico argumento
adicion2(12,9.6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-41-ccc831fdcd2a> in <cell line: 2>()
#       1 # Limitante que tiene adicion2 : Solo recibe un unico argumento
# ----> 2 adicion2(12,9.6)
#
# TypeError: adicion2() takes 1 positional argument but 2 were given

# %%
# Para definir una funcion con un numero variable de argumentos.
# Hay que anteponer el caracter * al argumento de la funcion
def adicion3(*numeros):
  sumaTotal = 0
  for i in numeros:
    sumaTotal = sumaTotal + i
  return sumaTotal

# %%
# ejemplito
adicion3(12)
# Out:
# 12

# %%
# ejemplito
adicion3(12,34,5)
# Out:
# 51

# %%
# ejemplito
adicion3(12,34,5,12,213,12,31,4,254,35,46,4,75,7,58,67,8976)
# Out:
# 9845

# %%
# la forma como esta implementada la funcion adicion3 nos ensela un nuevo tipo de implementacion

# Definamos una funcion con el siguiente comportamiento
# Si solo tiene dos argumentos : retorna el producto de los dos argumentos
# Si solo tiene 3 argumentos, retorna el promedio aritmetico
# Si la funcion se ejecuta con un numero distinto a 2 o 3 argumentos : retorna un mensaje de error

def Operaciones1(*argumentos):
  if len(argumentos) == 2 :
    return argumentos[0] * argumentos[1]
  elif len(argumentos) == 3 :
    return sum(argumentos)/len(argumentos)
  else:
    return "NUmero de argumentos invalido (Leer la documentacion)"

# %%
# Primera llamada/ejecucion de Operaciones1
Operaciones1()
# Out:
# 'NUmero de argumentos invalido (Leer la documentacion)'

# %%
# Segunda llamada/ejecucion de Operaciones1
Operaciones1(9.81)
# Out:
# 'NUmero de argumentos invalido (Leer la documentacion)'

# %%
# tercera llamada/ejecucion de Operaciones1
Operaciones1(12,10)
# Out:
# 120

# %%
# Cuarta llamada/ejecucion de Operaciones1
Operaciones1(14,8,2)
# Out:
# 8.0

# %%
# Al usar la estrategia anterior no podemos usar argumentos por nombres . Entonces
# aprender otra forma de implementar funciones

# Usemos **kwargs

def Operaciones2(**kwargs):
  """
  Calcula la suma de los elementos

  """
  # Vamos a considerar a kwargs como si fuera un diccionario
  sumaTotal = 0
  for llave,valor in kwargs.items():
    print(llave, valor)
    sumaTotal = sumaTotal + valor
  return sumaTotal

# %%
# ejemplito 1
Operaciones2(p1 = 12, p2 = 17, p3 = 3)
# Out:
# p1 12
# p2 17
# p3 3
# 32

# %%
# Ejemplito 2
dict_datos = {"g1": 9.812, "euler":2.719, "pi":3.14159}
Operaciones2(**dict_datos)
# Out:
# g1 9.812
# euler 2.719
# pi 3.14159
# 15.67259

# %%
# Ejemplito 3
Operaciones2(g1= 9.812, euler=2.719, pi=3.14159)
# Out:
# g1 9.812
# euler 2.719
# pi 3.14159
# 15.67259

# %%
# Obliguemos a que la funcion solo trabaje con los argumentos : c1 y c2
def Operaciones3(**kwargs):
  # verifiquemos que solo se tiene a c1 y c2 como argumentos
  if ( ("c1"  in list(kwargs.keys())) and ("c2"  in list(kwargs.keys())) ):
    print("jarvice tiene los argumentos adecuados :")
    print("\t Jarvice en linea ... ")
    # Puede continuar con un  numero de tareas determinado
  else:
    print("ERROR DE EJECUCION. Se Procede a hackear tu sistema")

# %%
# Primera prueba de Operaciones3
Operaciones3(x1 = 12, C1 = "17")
# Out:
# ERROR DE EJECUCION. Se Procede a hackear tu sistema

# %%
# Segunda prueba de Operaciones3
Operaciones3(c1 = 12, c2 = 3, c3 = "Adios mundo cruel")
# Out:
# jarvice tiene los argumentos adecuados :
# 	 Jarvice en linea ...

# %%
# Actualicemos a la funcion Operaciones3

def Operaciones3_Ver2(**kwargs):
  if len(list(kwargs.keys())) == 2:
    # verifiquemos que solo se tiene a c1 y c2 como argumentos
    if ( ("c1"  in list(kwargs.keys())) and ("c2"  in list(kwargs.keys())) ):
      print("jarvice tiene los argumentos adecuados :")
      print("\t Jarvice en linea ... ")
      # Puede continuar con un  numero de tareas determinado
    else:
      print("ERROR DE EJECUCION. Se Procede a hackear tu sistema")
  else:
    print("Numero de argumentos invalido")

# %%
# Primera prueba de Operaciones3_Ver2
Operaciones3_Ver2(c1 = 12, c2 = 3, c3 = "Adios mundo cruel")
# Out:
# Numero de argumentos invalido

# %%
# Segunda prueba de Operaciones3_Ver2
Operaciones3_Ver2(c1 = 12, c2 = 4)
# Out:
# jarvice tiene los argumentos adecuados :
# 	 Jarvice en linea ...

# %%
# tercera prueba
Operaciones3_Ver2(c1 = 12)
# Out:
# Numero de argumentos invalido
